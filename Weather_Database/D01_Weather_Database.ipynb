# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data.

# %% [markdown]
# 1. Create a set of 2,000 random latitudes / longitudes
# 2. Get the nearest city using citipy
# 3. Make an API call with OpenWeatherMap
# 4. Retrieve the following info:
#     - Latitude / longitude
#     - Maximum temperature
#     - % Humidity
#     - % Cloudiness
#     - Wind speed
#     - Weather description
# 5. Add the data to a DF
# 6. Export the DF as a csv file, saved as WeatherPy_Database.csv

# %% [markdown]
# #### Step 01
# Create a set of (at least) 2,000 random latitudes / longitudes

# %%
# Add Matplotlib inline magic command
# %matplotlib inline

#Import dependencies, libaries, & build the base URL
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

import requests

import time
from datetime import datetime

#Import the API key
from config import weather_api_key

#Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# #### Step 02
# Get the nearest city using the citipy module

# %%
#Generate a set of random latitude and logitude combos ()
lats = np.random.uniform(low=-90.000, high=90.000, size=14000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=14000)
lat_lngs = zip(lats, lngs)

#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

#Create a list to hold the cities
cities = []

#Identify the nearest city for each lat/long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 2803

# %% [markdown]
# #### Step 03
# Make an API call using OpenWeatherMap

# %% [markdown]
# #### Step 04
# Retrieve weather info including lat/long, max temp, % humidity, % cloudiness, windspeed, & weather description

# %%
#Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

#Loop through the cities in the list.
for i, city in enumerate(cities):
    
    #Group the cities in sets of 50 for logging
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log the URL, record, set numbers, and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count
    record_count += 1
    
    #Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        #Parse the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_feels = city_weather['main']['feels_like']
        city_min_temp = city_weather['main']['temp_min']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        #Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        
        #Append the city info into city_data list
        city_data.append({"City": city.title(),
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Feels Like': city_feels,
                          'Min Temp': city_min_temp,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Country': city_country,
                          'Weather Description': city_description,
                          'Date': city_date})
    #If there is an error, skip the city
    except:
        print("City not found. Skipping...")
        continue

#Indicate Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | oranjemund
# Processing Record 2 of Set 1 | chokurdakh
# Processing Record 3 of Set 1 | lamar
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | kodiak
# Processing Record 6 of Set 1 | tirumullaivasal
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | matara
# Processing Record 9 of Set 1 | kavieng
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | faanui
# Processing Record 12 of Set 1 | saint george
# Processing Record 13 of Set 1 | bonfim
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | taksimo
# Processing Record 16 of Set 1 | honningsvag
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | clyde river
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | dien bien
# City not found. Skipping...
# Processing Record 23 of Set 1 | fairbanks
# Processing Record 24 of Set 1 | hualmay
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | dongtai
# Processing Record 27 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 1 | kencong
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | cardedeu
# Processing Record 31 of Set 1 | saskylakh
# Processing Record 32 of Set 1 | srednekolymsk
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | isiro
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | nanortalik
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | lagoa
# Processing Record 40 of Set 1 | marzuq
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | pisco
# Processing Record 45 of Set 1 | ponta do sol
# Processing Record 46 of Set 1 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 47 of Set 1 | tshikapa
# Processing Record 48 of Set 1 | harper
# Processing Record 49 of Set 1 | ushuaia
# Processing Record 50 of Set 1 | san patricio
# Processing Record 1 of Set 2 | nola
# Processing Record 2 of Set 2 | port lincoln
# Processing Record 3 of Set 2 | cardston
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | rundu
# Processing Record 6 of Set 2 | north bend
# Processing Record 7 of Set 2 | mandera
# Processing Record 8 of Set 2 | kongoussi
# Processing Record 9 of Set 2 | shakawe
# Processing Record 10 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 2 | porto novo
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | saint-pierre
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | mackay
# Processing Record 17 of Set 2 | raahe
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | yantal
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | nioro
# Processing Record 24 of Set 2 | sindor
# Processing Record 25 of Set 2 | port augusta
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | fecamp
# Processing Record 29 of Set 2 | aswan
# Processing Record 30 of Set 2 | milkovo
# Processing Record 31 of Set 2 | wasilla
# Processing Record 32 of Set 2 | olga
# Processing Record 33 of Set 2 | olafsvik
# Processing Record 34 of Set 2 | mangai
# Processing Record 35 of Set 2 | imeni tsyurupy
# Processing Record 36 of Set 2 | pahrump
# Processing Record 37 of Set 2 | chokwe
# Processing Record 38 of Set 2 | chimoio
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 2 | sunrise manor
# Processing Record 43 of Set 2 | dunedin
# Processing Record 44 of Set 2 | vestmannaeyjar
# Processing Record 45 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | sur
# Processing Record 47 of Set 2 | kahului
# Processing Record 48 of Set 2 | wilkie
# Processing Record 49 of Set 2 | arman
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | asau
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | kyshtovka
# Processing Record 4 of Set 3 | guerrero negro
# Processing Record 5 of Set 3 | odweyne
# Processing Record 6 of Set 3 | nome
# Processing Record 7 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 3 | kisesa
# Processing Record 9 of Set 3 | matam
# Processing Record 10 of Set 3 | vostok
# Processing Record 11 of Set 3 | presidente epitacio
# Processing Record 12 of Set 3 | seymchan
# Processing Record 13 of Set 3 | oriximina
# Processing Record 14 of Set 3 | haines junction
# Processing Record 15 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 3 | alofi
# Processing Record 17 of Set 3 | florida
# Processing Record 18 of Set 3 | myitkyina
# Processing Record 19 of Set 3 | poum
# Processing Record 20 of Set 3 | vaitape
# Processing Record 21 of Set 3 | broken hill
# Processing Record 22 of Set 3 | nikolskoye
# Processing Record 23 of Set 3 | tharrawaddy
# City not found. Skipping...
# Processing Record 24 of Set 3 | mataura
# Processing Record 25 of Set 3 | hudiksvall
# Processing Record 26 of Set 3 | bakchar
# Processing Record 27 of Set 3 | rio gallegos
# Processing Record 28 of Set 3 | ojinaga
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | shihezi
# Processing Record 31 of Set 3 | santa rosa de viterbo
# Processing Record 32 of Set 3 | ribas do rio pardo
# Processing Record 33 of Set 3 | hirara
# Processing Record 34 of Set 3 | andevoranto
# City not found. Skipping...
# Processing Record 35 of Set 3 | porto calvo
# Processing Record 36 of Set 3 | kendari
# Processing Record 37 of Set 3 | labuhan
# Processing Record 38 of Set 3 | dwarka
# Processing Record 39 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 3 | macas
# Processing Record 42 of Set 3 | mount isa
# Processing Record 43 of Set 3 | dudinka
# Processing Record 44 of Set 3 | victoria
# Processing Record 45 of Set 3 | vila
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | eureka
# Processing Record 48 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 3 | tura
# Processing Record 50 of Set 3 | gat
# Processing Record 1 of Set 4 | costa rica
# Processing Record 2 of Set 4 | vao
# Processing Record 3 of Set 4 | henderson
# Processing Record 4 of Set 4 | omboue
# Processing Record 5 of Set 4 | lexington
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | bolshevik
# Processing Record 8 of Set 4 | airai
# Processing Record 9 of Set 4 | ust-nera
# Processing Record 10 of Set 4 | weiser
# Processing Record 11 of Set 4 | ahipara
# Processing Record 12 of Set 4 | agadez
# Processing Record 13 of Set 4 | sibolga
# Processing Record 14 of Set 4 | kaihua
# Processing Record 15 of Set 4 | usevya
# Processing Record 16 of Set 4 | sitka
# Processing Record 17 of Set 4 | flin flon
# Processing Record 18 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 4 | saint-augustin
# Processing Record 20 of Set 4 | hilo
# Processing Record 21 of Set 4 | erenhot
# Processing Record 22 of Set 4 | terre haute
# Processing Record 23 of Set 4 | bolshoye nagatkino
# Processing Record 24 of Set 4 | mar del plata
# Processing Record 25 of Set 4 | port blair
# Processing Record 26 of Set 4 | hasaki
# Processing Record 27 of Set 4 | kruisfontein
# Processing Record 28 of Set 4 | qaanaaq
# Processing Record 29 of Set 4 | pilar
# Processing Record 30 of Set 4 | kaitangata
# Processing Record 31 of Set 4 | cheremshan
# Processing Record 32 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 4 | lago da pedra
# Processing Record 34 of Set 4 | tuktoyaktuk
# Processing Record 35 of Set 4 | letterkenny
# Processing Record 36 of Set 4 | ko samui
# Processing Record 37 of Set 4 | cabo san lucas
# Processing Record 38 of Set 4 | cherskiy
# Processing Record 39 of Set 4 | severo-kurilsk
# Processing Record 40 of Set 4 | kasamwa
# Processing Record 41 of Set 4 | ust-kuyga
# Processing Record 42 of Set 4 | hithadhoo
# Processing Record 43 of Set 4 | lima
# Processing Record 44 of Set 4 | pundaguitan
# Processing Record 45 of Set 4 | ribeira grande
# Processing Record 46 of Set 4 | batemans bay
# Processing Record 47 of Set 4 | tabou
# Processing Record 48 of Set 4 | zhangye
# Processing Record 49 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 4 | sistranda
# Processing Record 1 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 5 | dubrovka
# Processing Record 3 of Set 5 | martapura
# Processing Record 4 of Set 5 | davila
# Processing Record 5 of Set 5 | hienghene
# Processing Record 6 of Set 5 | tasiilaq
# Processing Record 7 of Set 5 | guskhara
# Processing Record 8 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 5 | sorland
# Processing Record 10 of Set 5 | orda
# Processing Record 11 of Set 5 | aden
# Processing Record 12 of Set 5 | mugur-aksy
# Processing Record 13 of Set 5 | basyanovskiy
# City not found. Skipping...
# Processing Record 14 of Set 5 | mercedes
# Processing Record 15 of Set 5 | makakilo city
# Processing Record 16 of Set 5 | margate
# Processing Record 17 of Set 5 | vanimo
# Processing Record 18 of Set 5 | isangel
# Processing Record 19 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 5 | kerteh
# City not found. Skipping...
# Processing Record 21 of Set 5 | punta de bombon
# Processing Record 22 of Set 5 | dali
# Processing Record 23 of Set 5 | ban nahin
# Processing Record 24 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 5 | khatanga
# Processing Record 26 of Set 5 | bengkulu
# Processing Record 27 of Set 5 | udachnyy
# Processing Record 28 of Set 5 | prince albert
# Processing Record 29 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 5 | east london
# Processing Record 31 of Set 5 | bocaiuva
# Processing Record 32 of Set 5 | hojai
# Processing Record 33 of Set 5 | falam
# Processing Record 34 of Set 5 | ugoofaaru
# Processing Record 35 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 36 of Set 5 | coahuayana
# Processing Record 37 of Set 5 | grand gaube
# Processing Record 38 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 5 | tricase
# Processing Record 40 of Set 5 | hofn
# Processing Record 41 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 5 | makhachkala
# Processing Record 43 of Set 5 | sakakah
# Processing Record 44 of Set 5 | hukuntsi
# Processing Record 45 of Set 5 | bambous virieux
# Processing Record 46 of Set 5 | madingou
# Processing Record 47 of Set 5 | namibe
# Processing Record 48 of Set 5 | pevek
# Processing Record 49 of Set 5 | kon tum
# Processing Record 50 of Set 5 | laguna
# Processing Record 1 of Set 6 | kitimat
# Processing Record 2 of Set 6 | fort nelson
# Processing Record 3 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 4 of Set 6 | la ronge
# Processing Record 5 of Set 6 | puerto cortes
# City not found. Skipping...
# Processing Record 6 of Set 6 | ayagoz
# Processing Record 7 of Set 6 | cayenne
# Processing Record 8 of Set 6 | waddan
# Processing Record 9 of Set 6 | port macquarie
# Processing Record 10 of Set 6 | rurrenabaque
# Processing Record 11 of Set 6 | mayumba
# Processing Record 12 of Set 6 | mikumi
# Processing Record 13 of Set 6 | coruripe
# Processing Record 14 of Set 6 | shimoda
# Processing Record 15 of Set 6 | gamba
# Processing Record 16 of Set 6 | whitehorse
# Processing Record 17 of Set 6 | shashi
# Processing Record 18 of Set 6 | bogande
# Processing Record 19 of Set 6 | gladstone
# Processing Record 20 of Set 6 | ilulissat
# Processing Record 21 of Set 6 | chiredzi
# Processing Record 22 of Set 6 | tiksi
# Processing Record 23 of Set 6 | camacari
# Processing Record 24 of Set 6 | provideniya
# Processing Record 25 of Set 6 | fukue
# Processing Record 26 of Set 6 | souillac
# Processing Record 27 of Set 6 | dingle
# Processing Record 28 of Set 6 | biak
# Processing Record 29 of Set 6 | muravlenko
# Processing Record 30 of Set 6 | madang
# Processing Record 31 of Set 6 | bambanglipuro
# Processing Record 32 of Set 6 | camargo
# Processing Record 33 of Set 6 | villa maria
# Processing Record 34 of Set 6 | port elizabeth
# Processing Record 35 of Set 6 | zemio
# Processing Record 36 of Set 6 | lompoc
# Processing Record 37 of Set 6 | talara
# Processing Record 38 of Set 6 | urusha
# Processing Record 39 of Set 6 | waingapu
# Processing Record 40 of Set 6 | sabinopolis
# Processing Record 41 of Set 6 | sabang
# Processing Record 42 of Set 6 | bonavista
# Processing Record 43 of Set 6 | altay
# Processing Record 44 of Set 6 | beringovskiy
# Processing Record 45 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 46 of Set 6 | sorong
# Processing Record 47 of Set 6 | abonnema
# Processing Record 48 of Set 6 | fort beaufort
# Processing Record 49 of Set 6 | manado
# Processing Record 50 of Set 6 | tripoli
# Processing Record 1 of Set 7 | warrington
# Processing Record 2 of Set 7 | jarjis
# City not found. Skipping...
# Processing Record 3 of Set 7 | traverse city
# Processing Record 4 of Set 7 | khash
# Processing Record 5 of Set 7 | padong
# Processing Record 6 of Set 7 | svetlyy
# Processing Record 7 of Set 7 | talnakh
# Processing Record 8 of Set 7 | palmer
# Processing Record 9 of Set 7 | muncar
# Processing Record 10 of Set 7 | constitucion
# Processing Record 11 of Set 7 | coquimbo
# Processing Record 12 of Set 7 | farafenni
# Processing Record 13 of Set 7 | somerset
# Processing Record 14 of Set 7 | tuatapere
# Processing Record 15 of Set 7 | copiapo
# Processing Record 16 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 7 | mahebourg
# Processing Record 18 of Set 7 | stabat
# Processing Record 19 of Set 7 | turayf
# Processing Record 20 of Set 7 | yerbogachen
# Processing Record 21 of Set 7 | soldotna
# Processing Record 22 of Set 7 | rovaniemi
# Processing Record 23 of Set 7 | cape town
# Processing Record 24 of Set 7 | reconquista
# Processing Record 25 of Set 7 | leningradskiy
# Processing Record 26 of Set 7 | faya
# Processing Record 27 of Set 7 | sinop
# Processing Record 28 of Set 7 | lupiro
# Processing Record 29 of Set 7 | gao
# Processing Record 30 of Set 7 | merauke
# Processing Record 31 of Set 7 | vardo
# Processing Record 32 of Set 7 | coihaique
# Processing Record 33 of Set 7 | nouna
# Processing Record 34 of Set 7 | odesskoye
# Processing Record 35 of Set 7 | touros
# Processing Record 36 of Set 7 | kirby
# Processing Record 37 of Set 7 | freeport
# Processing Record 38 of Set 7 | yuli
# Processing Record 39 of Set 7 | san quintin
# Processing Record 40 of Set 7 | mocuba
# Processing Record 41 of Set 7 | sidi ali
# Processing Record 42 of Set 7 | madras
# Processing Record 43 of Set 7 | quatre cocos
# Processing Record 44 of Set 7 | kobayashi
# Processing Record 45 of Set 7 | anadyr
# Processing Record 46 of Set 7 | taoudenni
# Processing Record 47 of Set 7 | cochrane
# Processing Record 48 of Set 7 | kalmanka
# Processing Record 49 of Set 7 | miyako
# Processing Record 50 of Set 7 | atambua
# Processing Record 1 of Set 8 | tommot
# Processing Record 2 of Set 8 | abu samrah
# Processing Record 3 of Set 8 | batagay-alyta
# Processing Record 4 of Set 8 | takoradi
# Processing Record 5 of Set 8 | la macarena
# Processing Record 6 of Set 8 | sao felix do xingu
# Processing Record 7 of Set 8 | marabba
# Processing Record 8 of Set 8 | huarmey
# Processing Record 9 of Set 8 | necochea
# Processing Record 10 of Set 8 | bjornevatn
# Processing Record 11 of Set 8 | bohdan
# Processing Record 12 of Set 8 | tongchuan
# Processing Record 13 of Set 8 | keningau
# Processing Record 14 of Set 8 | oxapampa
# Processing Record 15 of Set 8 | itoman
# Processing Record 16 of Set 8 | deputatskiy
# Processing Record 17 of Set 8 | nador
# Processing Record 18 of Set 8 | general roca
# Processing Record 19 of Set 8 | vila franca do campo
# Processing Record 20 of Set 8 | thomasville
# Processing Record 21 of Set 8 | san juan
# Processing Record 22 of Set 8 | bilibino
# Processing Record 23 of Set 8 | okhotsk
# Processing Record 24 of Set 8 | jiuquan
# Processing Record 25 of Set 8 | arrifes
# Processing Record 26 of Set 8 | ust-tsilma
# Processing Record 27 of Set 8 | viedma
# Processing Record 28 of Set 8 | dawlatabad
# Processing Record 29 of Set 8 | padang
# Processing Record 30 of Set 8 | ballina
# Processing Record 31 of Set 8 | cravo norte
# Processing Record 32 of Set 8 | quimper
# Processing Record 33 of Set 8 | mahibadhoo
# Processing Record 34 of Set 8 | pak chong
# Processing Record 35 of Set 8 | taganak
# Processing Record 36 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 8 | meulaboh
# Processing Record 38 of Set 8 | hammerfest
# Processing Record 39 of Set 8 | cidreira
# Processing Record 40 of Set 8 | iguala
# Processing Record 41 of Set 8 | baft
# Processing Record 42 of Set 8 | sao filipe
# Processing Record 43 of Set 8 | hamada
# Processing Record 44 of Set 8 | armacao de pera
# Processing Record 45 of Set 8 | khurba
# Processing Record 46 of Set 8 | cabedelo
# Processing Record 47 of Set 8 | muroto
# Processing Record 48 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 8 | liverpool
# Processing Record 50 of Set 8 | karwar
# Processing Record 1 of Set 9 | navirai
# Processing Record 2 of Set 9 | buchanan
# Processing Record 3 of Set 9 | lavrentiya
# Processing Record 4 of Set 9 | bud
# Processing Record 5 of Set 9 | price
# Processing Record 6 of Set 9 | khanpur
# Processing Record 7 of Set 9 | oudtshoorn
# Processing Record 8 of Set 9 | kinwat
# Processing Record 9 of Set 9 | san cristobal
# Processing Record 10 of Set 9 | chernyshevskiy
# Processing Record 11 of Set 9 | atar
# Processing Record 12 of Set 9 | viesca
# Processing Record 13 of Set 9 | xuddur
# Processing Record 14 of Set 9 | guasdualito
# Processing Record 15 of Set 9 | nishihara
# Processing Record 16 of Set 9 | broome
# Processing Record 17 of Set 9 | lorengau
# Processing Record 18 of Set 9 | lumberton
# Processing Record 19 of Set 9 | iberia
# Processing Record 20 of Set 9 | hami
# Processing Record 21 of Set 9 | cuncolim
# Processing Record 22 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 23 of Set 9 | banjar
# Processing Record 24 of Set 9 | lebu
# Processing Record 25 of Set 9 | college
# Processing Record 26 of Set 9 | riyadh
# Processing Record 27 of Set 9 | ilhabela
# Processing Record 28 of Set 9 | riviere-au-renard
# Processing Record 29 of Set 9 | geraldton
# Processing Record 30 of Set 9 | ta khmau
# Processing Record 31 of Set 9 | champagnole
# Processing Record 32 of Set 9 | port-gentil
# Processing Record 33 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 34 of Set 9 | surt
# Processing Record 35 of Set 9 | warrnambool
# Processing Record 36 of Set 9 | pandhurna
# Processing Record 37 of Set 9 | mitsamiouli
# Processing Record 38 of Set 9 | berlevag
# Processing Record 39 of Set 9 | muros
# Processing Record 40 of Set 9 | plettenberg bay
# Processing Record 41 of Set 9 | katsuura
# Processing Record 42 of Set 9 | tutoia
# Processing Record 43 of Set 9 | klaksvik
# Processing Record 44 of Set 9 | norman wells
# Processing Record 45 of Set 9 | kaiserslautern
# Processing Record 46 of Set 9 | mattru
# Processing Record 47 of Set 9 | port hedland
# Processing Record 48 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 9 | zhezkazgan
# Processing Record 50 of Set 9 | saint-gedeon
# Processing Record 1 of Set 10 | pacasmayo
# Processing Record 2 of Set 10 | ilheus
# Processing Record 3 of Set 10 | charlestown
# Processing Record 4 of Set 10 | mangrol
# Processing Record 5 of Set 10 | olinda
# Processing Record 6 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 7 of Set 10 | alihe
# Processing Record 8 of Set 10 | lewiston
# Processing Record 9 of Set 10 | valparaiso
# Processing Record 10 of Set 10 | jati
# Processing Record 11 of Set 10 | roebourne
# Processing Record 12 of Set 10 | vanavara
# Processing Record 13 of Set 10 | marsh harbour
# Processing Record 14 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 15 of Set 10 | chuy
# Processing Record 16 of Set 10 | nuuk
# Processing Record 17 of Set 10 | palu
# Processing Record 18 of Set 10 | kuusamo
# Processing Record 19 of Set 10 | stolin
# Processing Record 20 of Set 10 | awjilah
# Processing Record 21 of Set 10 | nelson bay
# Processing Record 22 of Set 10 | rudbar
# Processing Record 23 of Set 10 | naron
# Processing Record 24 of Set 10 | kluang
# Processing Record 25 of Set 10 | husavik
# Processing Record 26 of Set 10 | ternate
# Processing Record 27 of Set 10 | raymondville
# Processing Record 28 of Set 10 | ulyanovo
# City not found. Skipping...
# Processing Record 29 of Set 10 | tanabi
# Processing Record 30 of Set 10 | wajir
# Processing Record 31 of Set 10 | gombong
# Processing Record 32 of Set 10 | lingyuan
# Processing Record 33 of Set 10 | izhmorskiy
# Processing Record 34 of Set 10 | le port
# Processing Record 35 of Set 10 | surgut
# Processing Record 36 of Set 10 | kurilsk
# Processing Record 37 of Set 10 | balikpapan
# Processing Record 38 of Set 10 | bodden town
# Processing Record 39 of Set 10 | nemuro
# Processing Record 40 of Set 10 | tvoroyri
# Processing Record 41 of Set 10 | narrabri
# Processing Record 42 of Set 10 | ixtapa
# Processing Record 43 of Set 10 | akureyri
# Processing Record 44 of Set 10 | atbasar
# Processing Record 45 of Set 10 | kondopoga
# Processing Record 46 of Set 10 | narsaq
# Processing Record 47 of Set 10 | najran
# Processing Record 48 of Set 10 | shestakovo
# Processing Record 49 of Set 10 | saldanha
# Processing Record 50 of Set 10 | tombouctou
# Processing Record 1 of Set 11 | mount gambier
# Processing Record 2 of Set 11 | pontal do parana
# Processing Record 3 of Set 11 | kangaatsiaq
# Processing Record 4 of Set 11 | celestun
# Processing Record 5 of Set 11 | yulara
# Processing Record 6 of Set 11 | gurgentepe
# Processing Record 7 of Set 11 | fortuna
# Processing Record 8 of Set 11 | bubaque
# Processing Record 9 of Set 11 | lasa
# Processing Record 10 of Set 11 | kholodnyy
# Processing Record 11 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 11 | menongue
# Processing Record 13 of Set 11 | san clemente
# Processing Record 14 of Set 11 | kayerkan
# Processing Record 15 of Set 11 | laem sing
# Processing Record 16 of Set 11 | hlukhiv
# Processing Record 17 of Set 11 | santa cruz
# Processing Record 18 of Set 11 | bluefield
# Processing Record 19 of Set 11 | witu
# Processing Record 20 of Set 11 | port-cartier
# Processing Record 21 of Set 11 | kenai
# Processing Record 22 of Set 11 | dhidhdhoo
# Processing Record 23 of Set 11 | finnsnes
# Processing Record 24 of Set 11 | sompeta
# Processing Record 25 of Set 11 | puerto carreno
# Processing Record 26 of Set 11 | safaqis
# City not found. Skipping...
# Processing Record 27 of Set 11 | boguchar
# Processing Record 28 of Set 11 | portland
# Processing Record 29 of Set 11 | almaznyy
# Processing Record 30 of Set 11 | champerico
# Processing Record 31 of Set 11 | murgab
# Processing Record 32 of Set 11 | inuvik
# Processing Record 33 of Set 11 | tessalit
# Processing Record 34 of Set 11 | sao joao da barra
# Processing Record 35 of Set 11 | kunming
# Processing Record 36 of Set 11 | medea
# Processing Record 37 of Set 11 | khovu-aksy
# Processing Record 38 of Set 11 | abu kamal
# Processing Record 39 of Set 11 | ribeira brava
# Processing Record 40 of Set 11 | vanderhoof
# Processing Record 41 of Set 11 | volchansk
# Processing Record 42 of Set 11 | raudeberg
# Processing Record 43 of Set 11 | batouri
# Processing Record 44 of Set 11 | safranbolu
# Processing Record 45 of Set 11 | la palma
# Processing Record 46 of Set 11 | grindavik
# Processing Record 47 of Set 11 | ryotsu
# Processing Record 48 of Set 11 | moindou
# Processing Record 49 of Set 11 | novikovo
# Processing Record 50 of Set 11 | ogbomosho
# Processing Record 1 of Set 12 | krasnoselkup
# Processing Record 2 of Set 12 | taguatinga
# Processing Record 3 of Set 12 | zhigansk
# Processing Record 4 of Set 12 | los llanos de aridane
# Processing Record 5 of Set 12 | usinsk
# Processing Record 6 of Set 12 | elko
# Processing Record 7 of Set 12 | voi
# Processing Record 8 of Set 12 | conakry
# Processing Record 9 of Set 12 | buraydah
# Processing Record 10 of Set 12 | mezen
# Processing Record 11 of Set 12 | batticaloa
# Processing Record 12 of Set 12 | sobolevo
# Processing Record 13 of Set 12 | vila velha
# Processing Record 14 of Set 12 | kieta
# Processing Record 15 of Set 12 | leh
# Processing Record 16 of Set 12 | brasileia
# Processing Record 17 of Set 12 | novaya lyada
# Processing Record 18 of Set 12 | dzaoudzi
# Processing Record 19 of Set 12 | wajima
# Processing Record 20 of Set 12 | thabazimbi
# Processing Record 21 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 22 of Set 12 | ambilobe
# Processing Record 23 of Set 12 | goure
# Processing Record 24 of Set 12 | olavarria
# Processing Record 25 of Set 12 | kununurra
# Processing Record 26 of Set 12 | dongsheng
# Processing Record 27 of Set 12 | shumskiy
# Processing Record 28 of Set 12 | ancud
# Processing Record 29 of Set 12 | aklavik
# Processing Record 30 of Set 12 | irbeyskoye
# Processing Record 31 of Set 12 | luganville
# Processing Record 32 of Set 12 | kloulklubed
# Processing Record 33 of Set 12 | port hardy
# Processing Record 34 of Set 12 | shiyan
# Processing Record 35 of Set 12 | omsukchan
# Processing Record 36 of Set 12 | waw
# Processing Record 37 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 38 of Set 12 | kokopo
# Processing Record 39 of Set 12 | wakkanai
# Processing Record 40 of Set 12 | moose factory
# Processing Record 41 of Set 12 | conceicao do mato dentro
# Processing Record 42 of Set 12 | el real de santa maria
# Processing Record 43 of Set 12 | avera
# Processing Record 44 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 45 of Set 12 | porto velho
# Processing Record 46 of Set 12 | chicama
# Processing Record 47 of Set 12 | synya
# Processing Record 48 of Set 12 | buritis
# Processing Record 49 of Set 12 | adrar
# Processing Record 50 of Set 12 | eidfjord
# Processing Record 1 of Set 13 | scarborough
# Processing Record 2 of Set 13 | acapulco
# Processing Record 3 of Set 13 | banda aceh
# Processing Record 4 of Set 13 | chara
# Processing Record 5 of Set 13 | darhan
# Processing Record 6 of Set 13 | alyangula
# Processing Record 7 of Set 13 | bayonet point
# Processing Record 8 of Set 13 | hamilton
# Processing Record 9 of Set 13 | naze
# Processing Record 10 of Set 13 | severnoye
# Processing Record 11 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 13 | quelimane
# Processing Record 13 of Set 13 | russell
# Processing Record 14 of Set 13 | goderich
# Processing Record 15 of Set 13 | luderitz
# Processing Record 16 of Set 13 | kathmandu
# Processing Record 17 of Set 13 | san jeronimo
# Processing Record 18 of Set 13 | sioux lookout
# Processing Record 19 of Set 13 | paamiut
# Processing Record 20 of Set 13 | ndiekro
# City not found. Skipping...
# Processing Record 21 of Set 13 | saint helens
# Processing Record 22 of Set 13 | kawambwa
# Processing Record 23 of Set 13 | maine-soroa
# Processing Record 24 of Set 13 | panaba
# Processing Record 25 of Set 13 | hastings
# Processing Record 26 of Set 13 | carutapera
# Processing Record 27 of Set 13 | roma
# Processing Record 28 of Set 13 | mahajanga
# Processing Record 29 of Set 13 | karratha
# Processing Record 30 of Set 13 | hashtrud
# Processing Record 31 of Set 13 | djibo
# Processing Record 32 of Set 13 | alice springs
# Processing Record 33 of Set 13 | ridgecrest
# Processing Record 34 of Set 13 | honiara
# Processing Record 35 of Set 13 | ganta
# Processing Record 36 of Set 13 | naifaru
# Processing Record 37 of Set 13 | fairview
# Processing Record 38 of Set 13 | mirnyy
# Processing Record 39 of Set 13 | aguimes
# Processing Record 40 of Set 13 | la primavera
# Processing Record 41 of Set 13 | slatinany
# Processing Record 42 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 43 of Set 13 | trincomalee
# Processing Record 44 of Set 13 | te anau
# Processing Record 45 of Set 13 | poronaysk
# Processing Record 46 of Set 13 | xiantao
# Processing Record 47 of Set 13 | knysna
# Processing Record 48 of Set 13 | yvetot
# Processing Record 49 of Set 13 | puerto del rosario
# Processing Record 50 of Set 13 | grand-santi
# Processing Record 1 of Set 14 | ostrovnoy
# Processing Record 2 of Set 14 | puerto escondido
# Processing Record 3 of Set 14 | axim
# Processing Record 4 of Set 14 | maarianhamina
# Processing Record 5 of Set 14 | anaconda
# Processing Record 6 of Set 14 | bowen
# Processing Record 7 of Set 14 | yatou
# Processing Record 8 of Set 14 | ciras
# City not found. Skipping...
# Processing Record 9 of Set 14 | chengmai
# City not found. Skipping...
# Processing Record 10 of Set 14 | daxian
# City not found. Skipping...
# Processing Record 11 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 12 of Set 14 | qiongshan
# Processing Record 13 of Set 14 | palauig
# Processing Record 14 of Set 14 | srandakan
# Processing Record 15 of Set 14 | kulhudhuffushi
# Processing Record 16 of Set 14 | sangar
# Processing Record 17 of Set 14 | kailua
# Processing Record 18 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 14 | westport
# Processing Record 20 of Set 14 | gayny
# Processing Record 21 of Set 14 | sungaipenuh
# Processing Record 22 of Set 14 | horadiz
# Processing Record 23 of Set 14 | vallenar
# Processing Record 24 of Set 14 | aushiger
# Processing Record 25 of Set 14 | tateyama
# Processing Record 26 of Set 14 | svetlogorsk
# Processing Record 27 of Set 14 | mizan teferi
# Processing Record 28 of Set 14 | bukama
# Processing Record 29 of Set 14 | vyazma
# Processing Record 30 of Set 14 | santa isabel
# Processing Record 31 of Set 14 | kavaratti
# Processing Record 32 of Set 14 | hobyo
# Processing Record 33 of Set 14 | lalin
# Processing Record 34 of Set 14 | beni
# Processing Record 35 of Set 14 | marsaxlokk
# Processing Record 36 of Set 14 | thinadhoo
# Processing Record 37 of Set 14 | gorontalo
# Processing Record 38 of Set 14 | diplo
# Processing Record 39 of Set 14 | ust-ishim
# Processing Record 40 of Set 14 | kodinsk
# Processing Record 41 of Set 14 | whithorn
# Processing Record 42 of Set 14 | diffa
# Processing Record 43 of Set 14 | skegness
# Processing Record 44 of Set 14 | khani
# Processing Record 45 of Set 14 | beloha
# Processing Record 46 of Set 14 | port moresby
# Processing Record 47 of Set 14 | piuma
# Processing Record 48 of Set 14 | kimbe
# Processing Record 49 of Set 14 | opuwo
# Processing Record 50 of Set 14 | flinders
# Processing Record 1 of Set 15 | naryan-mar
# Processing Record 2 of Set 15 | pierre
# Processing Record 3 of Set 15 | turan
# Processing Record 4 of Set 15 | mao
# Processing Record 5 of Set 15 | biltine
# Processing Record 6 of Set 15 | chippewa falls
# Processing Record 7 of Set 15 | sabha
# Processing Record 8 of Set 15 | waterloo
# Processing Record 9 of Set 15 | kousseri
# Processing Record 10 of Set 15 | blythe
# Processing Record 11 of Set 15 | kiunga
# Processing Record 12 of Set 15 | chardara
# Processing Record 13 of Set 15 | pangody
# Processing Record 14 of Set 15 | san andres
# Processing Record 15 of Set 15 | maues
# Processing Record 16 of Set 15 | miravci
# Processing Record 17 of Set 15 | uniontown
# Processing Record 18 of Set 15 | qaqortoq
# Processing Record 19 of Set 15 | bushehr
# Processing Record 20 of Set 15 | gazli
# Processing Record 21 of Set 15 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 22 of Set 15 | kupang
# Processing Record 23 of Set 15 | fez
# Processing Record 24 of Set 15 | balykshi
# Processing Record 25 of Set 15 | salalah
# Processing Record 26 of Set 15 | xifeng
# Processing Record 27 of Set 15 | tanda
# Processing Record 28 of Set 15 | tsimlyansk
# Processing Record 29 of Set 15 | havoysund
# Processing Record 30 of Set 15 | araouane
# Processing Record 31 of Set 15 | corning
# Processing Record 32 of Set 15 | maloy
# Processing Record 33 of Set 15 | dzhebariki-khaya
# Processing Record 34 of Set 15 | sahrak
# City not found. Skipping...
# Processing Record 35 of Set 15 | gberia fotombu
# Processing Record 36 of Set 15 | churapcha
# Processing Record 37 of Set 15 | burnie
# Processing Record 38 of Set 15 | buin
# Processing Record 39 of Set 15 | tezu
# Processing Record 40 of Set 15 | jos
# Processing Record 41 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 15 | antigonish
# Processing Record 43 of Set 15 | cabinda
# Processing Record 44 of Set 15 | morlaix
# Processing Record 45 of Set 15 | am timan
# Processing Record 46 of Set 15 | emba
# Processing Record 47 of Set 15 | guangyuan
# Processing Record 48 of Set 15 | ambikapur
# Processing Record 49 of Set 15 | gillette
# Processing Record 50 of Set 15 | limay
# Processing Record 1 of Set 16 | uniao da victoria
# City not found. Skipping...
# Processing Record 2 of Set 16 | genhe
# Processing Record 3 of Set 16 | kaabong
# Processing Record 4 of Set 16 | itarema
# Processing Record 5 of Set 16 | bandarbeyla
# Processing Record 6 of Set 16 | pangoa
# Processing Record 7 of Set 16 | mankapur
# Processing Record 8 of Set 16 | aykhal
# Processing Record 9 of Set 16 | atherton
# Processing Record 10 of Set 16 | priargunsk
# Processing Record 11 of Set 16 | antalaha
# Processing Record 12 of Set 16 | goryachegorsk
# Processing Record 13 of Set 16 | tabas
# Processing Record 14 of Set 16 | mandalgovi
# Processing Record 15 of Set 16 | burica
# City not found. Skipping...
# Processing Record 16 of Set 16 | cam ranh
# Processing Record 17 of Set 16 | keti bandar
# Processing Record 18 of Set 16 | novyy urengoy
# Processing Record 19 of Set 16 | piney green
# Processing Record 20 of Set 16 | bantry
# Processing Record 21 of Set 16 | vagamo
# Processing Record 22 of Set 16 | along
# Processing Record 23 of Set 16 | tobermory
# Processing Record 24 of Set 16 | cockburn town
# Processing Record 25 of Set 16 | phan rang
# City not found. Skipping...
# Processing Record 26 of Set 16 | campbell river
# Processing Record 27 of Set 16 | ust-omchug
# Processing Record 28 of Set 16 | fevralsk
# City not found. Skipping...
# Processing Record 29 of Set 16 | lakeway
# Processing Record 30 of Set 16 | duz
# City not found. Skipping...
# Processing Record 31 of Set 16 | mzimba
# Processing Record 32 of Set 16 | urzhum
# Processing Record 33 of Set 16 | neuquen
# Processing Record 34 of Set 16 | berezovka
# Processing Record 35 of Set 16 | yangjiang
# Processing Record 36 of Set 16 | hermiston
# Processing Record 37 of Set 16 | abalak
# Processing Record 38 of Set 16 | barranca
# Processing Record 39 of Set 16 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 16 | komsomolskiy
# Processing Record 41 of Set 16 | colquiri
# Processing Record 42 of Set 16 | san isidro
# Processing Record 43 of Set 16 | pimenta bueno
# Processing Record 44 of Set 16 | yeniseysk
# Processing Record 45 of Set 16 | soderhamn
# Processing Record 46 of Set 16 | bereda
# Processing Record 47 of Set 16 | esperance
# Processing Record 48 of Set 16 | mehamn
# Processing Record 49 of Set 16 | umm kaddadah
# Processing Record 50 of Set 16 | lamu
# Processing Record 1 of Set 17 | karachi
# Processing Record 2 of Set 17 | traiguen
# Processing Record 3 of Set 17 | callaway
# Processing Record 4 of Set 17 | yeppoon
# Processing Record 5 of Set 17 | belmonte
# Processing Record 6 of Set 17 | mahaicony
# City not found. Skipping...
# Processing Record 7 of Set 17 | sioni
# Processing Record 8 of Set 17 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 9 of Set 17 | berck
# Processing Record 10 of Set 17 | pemangkat
# Processing Record 11 of Set 17 | tomigusuku
# Processing Record 12 of Set 17 | skalistyy
# City not found. Skipping...
# Processing Record 13 of Set 17 | mecca
# Processing Record 14 of Set 17 | kungurtug
# Processing Record 15 of Set 17 | san vicente
# Processing Record 16 of Set 17 | belyy yar
# Processing Record 17 of Set 17 | molina
# Processing Record 18 of Set 17 | akhtanizovskaya
# Processing Record 19 of Set 17 | manakara
# Processing Record 20 of Set 17 | kaeo
# Processing Record 21 of Set 17 | esterhazy
# Processing Record 22 of Set 17 | esso
# Processing Record 23 of Set 17 | zhoucheng
# Processing Record 24 of Set 17 | dukat
# Processing Record 25 of Set 17 | bulgan
# Processing Record 26 of Set 17 | miramar
# Processing Record 27 of Set 17 | nabire
# Processing Record 28 of Set 17 | lambarene
# Processing Record 29 of Set 17 | kawana waters
# City not found. Skipping...
# Processing Record 30 of Set 17 | san felipe
# Processing Record 31 of Set 17 | bathsheba
# Processing Record 32 of Set 17 | greytown
# Processing Record 33 of Set 17 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 17 | toora-khem
# Processing Record 35 of Set 17 | pangkalanbuun
# Processing Record 36 of Set 17 | magadan
# Processing Record 37 of Set 17 | boffa
# Processing Record 38 of Set 17 | tuggurt
# City not found. Skipping...
# Processing Record 39 of Set 17 | bonthe
# Processing Record 40 of Set 17 | ambon
# Processing Record 41 of Set 17 | urfa
# City not found. Skipping...
# Processing Record 42 of Set 17 | derzhavinsk
# Processing Record 43 of Set 17 | tazovskiy
# Processing Record 44 of Set 17 | cozumel
# Processing Record 45 of Set 17 | buariki
# City not found. Skipping...
# Processing Record 46 of Set 17 | virginia beach
# Processing Record 47 of Set 17 | hibbing
# Processing Record 48 of Set 17 | hokitika
# Processing Record 49 of Set 17 | arrecife
# Processing Record 50 of Set 17 | marystown
# Processing Record 1 of Set 18 | bairiki
# Processing Record 2 of Set 18 | santarem
# Processing Record 3 of Set 18 | yakeshi
# Processing Record 4 of Set 18 | kidal
# Processing Record 5 of Set 18 | shenjiamen
# Processing Record 6 of Set 18 | key biscayne
# Processing Record 7 of Set 18 | torfyanoy
# Processing Record 8 of Set 18 | angoram
# Processing Record 9 of Set 18 | tyukhtet
# Processing Record 10 of Set 18 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 18 | kudat
# Processing Record 12 of Set 18 | ostersund
# Processing Record 13 of Set 18 | alamosa
# Processing Record 14 of Set 18 | conceicao do araguaia
# Processing Record 15 of Set 18 | ingham
# Processing Record 16 of Set 18 | lodwar
# Processing Record 17 of Set 18 | nyurba
# Processing Record 18 of Set 18 | ortakoy
# Processing Record 19 of Set 18 | luz
# Processing Record 20 of Set 18 | shahr-e babak
# Processing Record 21 of Set 18 | rawannawi
# City not found. Skipping...
# Processing Record 22 of Set 18 | lata
# Processing Record 23 of Set 18 | mbaiki
# Processing Record 24 of Set 18 | abha
# Processing Record 25 of Set 18 | waipawa
# Processing Record 26 of Set 18 | jasper
# Processing Record 27 of Set 18 | dakar
# Processing Record 28 of Set 18 | chapaevsk
# Processing Record 29 of Set 18 | rawson
# Processing Record 30 of Set 18 | inirida
# Processing Record 31 of Set 18 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 18 | rocha
# Processing Record 33 of Set 18 | zonguldak
# Processing Record 34 of Set 18 | uray
# Processing Record 35 of Set 18 | barra patuca
# Processing Record 36 of Set 18 | kupino
# Processing Record 37 of Set 18 | jabiru
# City not found. Skipping...
# Processing Record 38 of Set 18 | vestmanna
# Processing Record 39 of Set 18 | chatham
# Processing Record 40 of Set 18 | camacha
# Processing Record 41 of Set 18 | mitu
# Processing Record 42 of Set 18 | skagastrond
# City not found. Skipping...
# Processing Record 43 of Set 18 | ratnagiri
# Processing Record 44 of Set 18 | newport beach
# Processing Record 45 of Set 18 | fianga
# City not found. Skipping...
# Processing Record 46 of Set 18 | vangaindrano
# Processing Record 47 of Set 18 | barabai
# Processing Record 48 of Set 18 | kutum
# Processing Record 49 of Set 18 | sai buri
# Processing Record 50 of Set 18 | south venice
# Processing Record 1 of Set 19 | saint-francois
# Processing Record 2 of Set 19 | asfi
# Processing Record 3 of Set 19 | majene
# Processing Record 4 of Set 19 | gardan diwal
# City not found. Skipping...
# Processing Record 5 of Set 19 | wanning
# Processing Record 6 of Set 19 | caravelas
# Processing Record 7 of Set 19 | aliwal north
# Processing Record 8 of Set 19 | alvand
# Processing Record 9 of Set 19 | andros town
# Processing Record 10 of Set 19 | karpogory
# Processing Record 11 of Set 19 | kainantu
# Processing Record 12 of Set 19 | danshui
# Processing Record 13 of Set 19 | onverwacht
# Processing Record 14 of Set 19 | aksu
# Processing Record 15 of Set 19 | lethem
# Processing Record 16 of Set 19 | achisay
# City not found. Skipping...
# Processing Record 17 of Set 19 | maniitsoq
# Processing Record 18 of Set 19 | cedar city
# Processing Record 19 of Set 19 | labytnangi
# Processing Record 20 of Set 19 | vitim
# Processing Record 21 of Set 19 | tubruq
# City not found. Skipping...
# Processing Record 22 of Set 19 | iaciara
# Processing Record 23 of Set 19 | byron bay
# Processing Record 24 of Set 19 | tacuarembo
# Processing Record 25 of Set 19 | vicuna
# Processing Record 26 of Set 19 | zdvinsk
# Processing Record 27 of Set 19 | wewak
# Processing Record 28 of Set 19 | belebey
# Processing Record 29 of Set 19 | kardla
# Processing Record 30 of Set 19 | harrisonville
# Processing Record 31 of Set 19 | santiago del estero
# Processing Record 32 of Set 19 | morondava
# Processing Record 33 of Set 19 | mumford
# Processing Record 34 of Set 19 | kiomboi
# Processing Record 35 of Set 19 | bhan
# Processing Record 36 of Set 19 | nybro
# Processing Record 37 of Set 19 | doha
# Processing Record 38 of Set 19 | victor harbor
# Processing Record 39 of Set 19 | codajas
# Processing Record 40 of Set 19 | beidao
# Processing Record 41 of Set 19 | tulun
# Processing Record 42 of Set 19 | abramovka
# Processing Record 43 of Set 19 | rioja
# Processing Record 44 of Set 19 | chernogorsk
# Processing Record 45 of Set 19 | zalantun
# Processing Record 46 of Set 19 | garissa
# Processing Record 47 of Set 19 | matamoros
# Processing Record 48 of Set 19 | winnemucca
# Processing Record 49 of Set 19 | porto santo
# Processing Record 50 of Set 19 | beroun
# Processing Record 1 of Set 20 | onguday
# Processing Record 2 of Set 20 | mananjary
# Processing Record 3 of Set 20 | barra do corda
# Processing Record 4 of Set 20 | jumla
# Processing Record 5 of Set 20 | norfolk
# Processing Record 6 of Set 20 | antofagasta
# Processing Record 7 of Set 20 | tomatlan
# Processing Record 8 of Set 20 | xihua
# Processing Record 9 of Set 20 | sri aman
# Processing Record 10 of Set 20 | seminole
# Processing Record 11 of Set 20 | tual
# Processing Record 12 of Set 20 | boende
# Processing Record 13 of Set 20 | kalanchak
# Processing Record 14 of Set 20 | mayna
# Processing Record 15 of Set 20 | nizhnevartovsk
# Processing Record 16 of Set 20 | lambayeque
# Processing Record 17 of Set 20 | vrangel
# Processing Record 18 of Set 20 | chastoozerye
# City not found. Skipping...
# Processing Record 19 of Set 20 | mana
# Processing Record 20 of Set 20 | laiagam
# City not found. Skipping...
# Processing Record 21 of Set 20 | ouadda
# Processing Record 22 of Set 20 | krizevci
# Processing Record 23 of Set 20 | verkhnevilyuysk
# Processing Record 24 of Set 20 | sola
# Processing Record 25 of Set 20 | atikokan
# Processing Record 26 of Set 20 | anda
# Processing Record 27 of Set 20 | shelburne
# Processing Record 28 of Set 20 | pak phanang
# Processing Record 29 of Set 20 | grimshaw
# Processing Record 30 of Set 20 | borjomi
# Processing Record 31 of Set 20 | inhambane
# Processing Record 32 of Set 20 | kudahuvadhoo
# Processing Record 33 of Set 20 | havelock
# Processing Record 34 of Set 20 | garoua
# Processing Record 35 of Set 20 | victoria point
# Processing Record 36 of Set 20 | cojumatlan
# City not found. Skipping...
# Processing Record 37 of Set 20 | leonidovo
# Processing Record 38 of Set 20 | alassio
# Processing Record 39 of Set 20 | george town
# Processing Record 40 of Set 20 | fort-shevchenko
# Processing Record 41 of Set 20 | humberto de campos
# Processing Record 42 of Set 20 | kilakarai
# Processing Record 43 of Set 20 | shangzhi
# Processing Record 44 of Set 20 | kandrian
# Processing Record 45 of Set 20 | roseburg
# Processing Record 46 of Set 20 | tungor
# Processing Record 47 of Set 20 | namanga
# Processing Record 48 of Set 20 | sept-iles
# Processing Record 49 of Set 20 | eskasem
# City not found. Skipping...
# Processing Record 50 of Set 20 | oksfjord
# Processing Record 1 of Set 21 | aljezur
# Processing Record 2 of Set 21 | ketchikan
# Processing Record 3 of Set 21 | kroya
# Processing Record 4 of Set 21 | bur gabo
# City not found. Skipping...
# Processing Record 5 of Set 21 | perth
# Processing Record 6 of Set 21 | northam
# Processing Record 7 of Set 21 | nieuw amsterdam
# Processing Record 8 of Set 21 | russellville
# Processing Record 9 of Set 21 | providencia
# Processing Record 10 of Set 21 | burns lake
# Processing Record 11 of Set 21 | saint-georges
# Processing Record 12 of Set 21 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 21 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 21 | yinchuan
# Processing Record 15 of Set 21 | muyezerskiy
# Processing Record 16 of Set 21 | innisfail
# Processing Record 17 of Set 21 | loa janan
# Processing Record 18 of Set 21 | yermakovskoye
# Processing Record 19 of Set 21 | muzhi
# Processing Record 20 of Set 21 | charters towers
# Processing Record 21 of Set 21 | jimo
# Processing Record 22 of Set 21 | jalu
# Processing Record 23 of Set 21 | peterhead
# Processing Record 24 of Set 21 | horsens
# Processing Record 25 of Set 21 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 21 | belaya gora
# Processing Record 27 of Set 21 | sooke
# Processing Record 28 of Set 21 | sinnamary
# Processing Record 29 of Set 21 | muriwai beach
# Processing Record 30 of Set 21 | walvis bay
# Processing Record 31 of Set 21 | ivanava
# Processing Record 32 of Set 21 | natal
# Processing Record 33 of Set 21 | iglino
# Processing Record 34 of Set 21 | bac lieu
# Processing Record 35 of Set 21 | yertsevo
# Processing Record 36 of Set 21 | kentau
# Processing Record 37 of Set 21 | kade
# Processing Record 38 of Set 21 | mamu kanjan
# Processing Record 39 of Set 21 | megion
# Processing Record 40 of Set 21 | egvekinot
# Processing Record 41 of Set 21 | sunrise
# Processing Record 42 of Set 21 | ganzhou
# Processing Record 43 of Set 21 | ulaangom
# Processing Record 44 of Set 21 | xining
# Processing Record 45 of Set 21 | ouallam
# Processing Record 46 of Set 21 | sarangani
# Processing Record 47 of Set 21 | robertsganj
# Processing Record 48 of Set 21 | ambanja
# Processing Record 49 of Set 21 | jijiga
# Processing Record 50 of Set 21 | codrington
# Processing Record 1 of Set 22 | la paz
# Processing Record 2 of Set 22 | juifang
# City not found. Skipping...
# Processing Record 3 of Set 22 | niteroi
# Processing Record 4 of Set 22 | safwah
# City not found. Skipping...
# Processing Record 5 of Set 22 | dalnerechensk
# Processing Record 6 of Set 22 | lakatoro
# Processing Record 7 of Set 22 | qurayyat
# Processing Record 8 of Set 22 | manavalakurichi
# Processing Record 9 of Set 22 | aranos
# Processing Record 10 of Set 22 | baykit
# Processing Record 11 of Set 22 | gobabis
# Processing Record 12 of Set 22 | poros
# Processing Record 13 of Set 22 | chegutu
# Processing Record 14 of Set 22 | afrikanda
# Processing Record 15 of Set 22 | aloleng
# Processing Record 16 of Set 22 | sakaraha
# Processing Record 17 of Set 22 | pochutla
# Processing Record 18 of Set 22 | baturaja
# Processing Record 19 of Set 22 | vilyuysk
# Processing Record 20 of Set 22 | tilichiki
# Processing Record 21 of Set 22 | bilma
# Processing Record 22 of Set 22 | mariinsk
# Processing Record 23 of Set 22 | ginda
# Processing Record 24 of Set 22 | tevaitoa
# Processing Record 25 of Set 22 | brae
# Processing Record 26 of Set 22 | saravan
# Processing Record 27 of Set 22 | berbera
# Processing Record 28 of Set 22 | balashov
# Processing Record 29 of Set 22 | luau
# Processing Record 30 of Set 22 | samarai
# Processing Record 31 of Set 22 | galiwinku
# City not found. Skipping...
# Processing Record 32 of Set 22 | uddevalla
# Processing Record 33 of Set 22 | pervomayskoye
# Processing Record 34 of Set 22 | teguise
# Processing Record 35 of Set 22 | mastic beach
# Processing Record 36 of Set 22 | pietarsaari
# Processing Record 37 of Set 22 | nguruka
# Processing Record 38 of Set 22 | weifang
# Processing Record 39 of Set 22 | songjianghe
# Processing Record 40 of Set 22 | richards bay
# ...
# Processing Record 44 of Set 49 | horki
# Processing Record 45 of Set 49 | birao
# Processing Record 46 of Set 49 | giyon
# Processing Record 47 of Set 49 | cortez
# Processing Record 48 of Set 49 | turbat
# Processing Record 49 of Set 49 | pafos
# Processing Record 50 of Set 49 | kutina
# Processing Record 1 of Set 50 | guarapari
# Processing Record 2 of Set 50 | lohja
# Processing Record 3 of Set 50 | chom bung
# City not found. Skipping...
# Processing Record 4 of Set 50 | keetmanshoop
# Processing Record 5 of Set 50 | zambezi
# Processing Record 6 of Set 50 | uige
# Processing Record 7 of Set 50 | harwich
# Processing Record 8 of Set 50 | kaupanger
# Processing Record 9 of Set 50 | leiyang
# Processing Record 10 of Set 50 | sfantu gheorghe
# Processing Record 11 of Set 50 | shangrao
# Processing Record 12 of Set 50 | sumbe
# Processing Record 13 of Set 50 | storforshei
# Processing Record 14 of Set 50 | carhuaz
# Processing Record 15 of Set 50 | nenjiang
# Processing Record 16 of Set 50 | corn island
# Processing Record 17 of Set 50 | krasnouralsk
# Processing Record 18 of Set 50 | porangatu
# Processing Record 19 of Set 50 | grande-synthe
# Processing Record 20 of Set 50 | mutis
# Processing Record 21 of Set 50 | tamworth
# Processing Record 22 of Set 50 | bella vista
# Processing Record 23 of Set 50 | bontang
# Processing Record 24 of Set 50 | mpanda
# Processing Record 25 of Set 50 | hailey
# Processing Record 26 of Set 50 | jawhar
# Processing Record 27 of Set 50 | witney
# Processing Record 28 of Set 50 | campoverde
# Processing Record 29 of Set 50 | renukut
# Processing Record 30 of Set 50 | juneau
# Processing Record 31 of Set 50 | dauphin
# Processing Record 32 of Set 50 | vila do maio
# Processing Record 33 of Set 50 | kuching
# Processing Record 34 of Set 50 | kapit
# Processing Record 35 of Set 50 | condega
# Processing Record 36 of Set 50 | bacau
# Processing Record 37 of Set 50 | kinshasa
# Processing Record 38 of Set 50 | veracruz
# Processing Record 39 of Set 50 | nouakchott
# Processing Record 40 of Set 50 | aldan
# Processing Record 41 of Set 50 | florianopolis
# Processing Record 42 of Set 50 | alba
# Processing Record 43 of Set 50 | otjimbingwe
# Processing Record 44 of Set 50 | lewisporte
# Processing Record 45 of Set 50 | guiyang
# Processing Record 46 of Set 50 | uusikaupunki
# Processing Record 47 of Set 50 | kibakwe
# Processing Record 48 of Set 50 | barcelos
# Processing Record 49 of Set 50 | tofield
# Processing Record 50 of Set 50 | sao francisco
# Processing Record 1 of Set 51 | skelleftea
# Processing Record 2 of Set 51 | valdemarpils
# Processing Record 3 of Set 51 | balakhninskiy
# Processing Record 4 of Set 51 | jatiroto
# Processing Record 5 of Set 51 | bata
# Processing Record 6 of Set 51 | paris
# Processing Record 7 of Set 51 | apatou
# Processing Record 8 of Set 51 | haukipudas
# Processing Record 9 of Set 51 | cuxhaven
# Processing Record 10 of Set 51 | kamaishi
# Processing Record 11 of Set 51 | kouroussa
# Processing Record 12 of Set 51 | puqi
# Processing Record 13 of Set 51 | gurgan
# City not found. Skipping...
# Processing Record 14 of Set 51 | coxim
# Processing Record 15 of Set 51 | paragominas
# Processing Record 16 of Set 51 | leshukonskoye
# Processing Record 17 of Set 51 | warwick
# Processing Record 18 of Set 51 | filingue
# Processing Record 19 of Set 51 | labuan
# Processing Record 20 of Set 51 | yantzaza
# Processing Record 21 of Set 51 | san-pedro
# Processing Record 22 of Set 51 | centralia
# Processing Record 23 of Set 51 | neftcala
# Processing Record 24 of Set 51 | platonovka
# Processing Record 25 of Set 51 | ocos
# Processing Record 26 of Set 51 | tatawin
# Processing Record 27 of Set 51 | manggar
# Processing Record 28 of Set 51 | culebra
# Processing Record 29 of Set 51 | piranshahr
# Processing Record 30 of Set 51 | robertsport
# Processing Record 31 of Set 51 | toamasina
# Processing Record 32 of Set 51 | kaohsiung
# Processing Record 33 of Set 51 | ayan
# Processing Record 34 of Set 51 | saint pete beach
# Processing Record 35 of Set 51 | bagdarin
# Processing Record 36 of Set 51 | agva
# City not found. Skipping...
# Processing Record 37 of Set 51 | krk
# Processing Record 38 of Set 51 | ankazoabo
# Processing Record 39 of Set 51 | malinyi
# Processing Record 40 of Set 51 | zhanakorgan
# Processing Record 41 of Set 51 | arlit
# Processing Record 42 of Set 51 | alto piquiri
# Processing Record 43 of Set 51 | haapsalu
# Processing Record 44 of Set 51 | haimen
# Processing Record 45 of Set 51 | belfast
# Processing Record 46 of Set 51 | wiarton
# Processing Record 47 of Set 51 | escanaba
# Processing Record 48 of Set 51 | gua musang
# Processing Record 49 of Set 51 | vredefort
# Processing Record 50 of Set 51 | castlegar
# Processing Record 1 of Set 52 | badiraguato
# Processing Record 2 of Set 52 | puka
# Processing Record 3 of Set 52 | daru
# Processing Record 4 of Set 52 | klaebu
# Processing Record 5 of Set 52 | erzin
# Processing Record 6 of Set 52 | bunia
# Processing Record 7 of Set 52 | jaguaruna
# Processing Record 8 of Set 52 | bolshoy lug
# Processing Record 9 of Set 52 | mocorito
# Processing Record 10 of Set 52 | setermoen
# Processing Record 11 of Set 52 | koulamoutou
# Processing Record 12 of Set 52 | colac
# Processing Record 13 of Set 52 | allapalli
# Processing Record 14 of Set 52 | turmalina
# Processing Record 15 of Set 52 | pangai
# Processing Record 16 of Set 52 | xingtai
# Processing Record 17 of Set 52 | el alto
# Processing Record 18 of Set 52 | taburao
# City not found. Skipping...
# Processing Record 19 of Set 52 | pemberton
# Processing Record 20 of Set 52 | ginir
# Processing Record 21 of Set 52 | chernyshevsk
# Processing Record 22 of Set 52 | severomorsk
# Processing Record 23 of Set 52 | amarillo
# Processing Record 24 of Set 52 | concepcion
# Processing Record 25 of Set 52 | hays
# Processing Record 26 of Set 52 | stavern
# Processing Record 27 of Set 52 | amboasary
# Processing Record 28 of Set 52 | alot
# Processing Record 29 of Set 52 | krasnyy chikoy
# Processing Record 30 of Set 52 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 52 | phalodi
# Processing Record 32 of Set 52 | lask
# Processing Record 33 of Set 52 | marrakesh
# Processing Record 34 of Set 52 | zhongxing
# Processing Record 35 of Set 52 | kishi
# Processing Record 36 of Set 52 | massafra
# Processing Record 37 of Set 52 | rebrikha
# Processing Record 38 of Set 52 | san ramon
# Processing Record 39 of Set 52 | sibu
# Processing Record 40 of Set 52 | kushima
# Processing Record 41 of Set 52 | snezhnogorsk
# Processing Record 42 of Set 52 | nagtipunan
# Processing Record 43 of Set 52 | udarnyy
# Processing Record 44 of Set 52 | stanghelle
# Processing Record 45 of Set 52 | palaikastron
# Processing Record 46 of Set 52 | kropotkin
# Processing Record 47 of Set 52 | qinzhou
# Processing Record 48 of Set 52 | senneterre
# Processing Record 49 of Set 52 | salinas
# Processing Record 50 of Set 52 | szigetvar
# Processing Record 1 of Set 53 | tres arroyos
# Processing Record 2 of Set 53 | binika
# Processing Record 3 of Set 53 | tasbuget
# City not found. Skipping...
# Processing Record 4 of Set 53 | cam pha
# City not found. Skipping...
# Processing Record 5 of Set 53 | anchorage
# Processing Record 6 of Set 53 | huautla
# Processing Record 7 of Set 53 | lermontovka
# Processing Record 8 of Set 53 | chongwe
# Processing Record 9 of Set 53 | geresk
# City not found. Skipping...
# Processing Record 10 of Set 53 | redding
# Processing Record 11 of Set 53 | crib point
# Processing Record 12 of Set 53 | is
# City not found. Skipping...
# Processing Record 13 of Set 53 | nyagan
# Processing Record 14 of Set 53 | yelanskiy
# Processing Record 15 of Set 53 | abnub
# Processing Record 16 of Set 53 | beihai
# Processing Record 17 of Set 53 | martaban
# Processing Record 18 of Set 53 | dandong
# Processing Record 19 of Set 53 | san bernardo
# Processing Record 20 of Set 53 | arona
# Processing Record 21 of Set 53 | wukari
# Processing Record 22 of Set 53 | vermilion
# Processing Record 23 of Set 53 | del rio
# Processing Record 24 of Set 53 | saint-louis
# Processing Record 25 of Set 53 | antibes
# Processing Record 26 of Set 53 | sonoita
# Processing Record 27 of Set 53 | azuaga
# Processing Record 28 of Set 53 | mokhotlong
# Processing Record 29 of Set 53 | bolobo
# Processing Record 30 of Set 53 | benghazi
# Processing Record 31 of Set 53 | turzovka
# Processing Record 32 of Set 53 | fort saint james
# Processing Record 33 of Set 53 | bayburt
# Processing Record 34 of Set 53 | tchollire
# Processing Record 35 of Set 53 | marienburg
# Processing Record 36 of Set 53 | goya
# Processing Record 37 of Set 53 | cegled
# Processing Record 38 of Set 53 | kadykchan
# City not found. Skipping...
# Processing Record 39 of Set 53 | tak
# Processing Record 40 of Set 53 | samoylovka
# Processing Record 41 of Set 53 | cameta
# Processing Record 42 of Set 53 | klaeng
# Processing Record 43 of Set 53 | kvitok
# Processing Record 44 of Set 53 | puerto madryn
# Processing Record 45 of Set 53 | williamsport
# Processing Record 46 of Set 53 | rivers
# Processing Record 47 of Set 53 | malinovoye ozero
# Processing Record 48 of Set 53 | kaizuka
# Processing Record 49 of Set 53 | ringkobing
# Processing Record 50 of Set 53 | baymak
# Processing Record 1 of Set 54 | goiatuba
# Processing Record 2 of Set 54 | zhetybay
# City not found. Skipping...
# Processing Record 3 of Set 54 | rabat
# Processing Record 4 of Set 54 | bolama
# Processing Record 5 of Set 54 | metro
# Processing Record 6 of Set 54 | sheregesh
# Processing Record 7 of Set 54 | storm lake
# Processing Record 8 of Set 54 | gadwal
# Processing Record 9 of Set 54 | avanigadda
# Processing Record 10 of Set 54 | itaocara
# Processing Record 11 of Set 54 | ocampo
# Processing Record 12 of Set 54 | hakui
# Processing Record 13 of Set 54 | el faiyum
# City not found. Skipping...
# Processing Record 14 of Set 54 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 54 | bokspits
# City not found. Skipping...
# Processing Record 16 of Set 54 | shkotovo-26
# City not found. Skipping...
# Processing Record 17 of Set 54 | baicheng
# Processing Record 18 of Set 54 | yakshur-bodya
# City not found. Skipping...
# Processing Record 19 of Set 54 | santa barbara
# Processing Record 20 of Set 54 | zhanatas
# City not found. Skipping...
# Processing Record 21 of Set 54 | tabialan
# City not found. Skipping...
# Processing Record 22 of Set 54 | leeuwarden
# Processing Record 23 of Set 54 | pizhanka
# Processing Record 24 of Set 54 | brownfield
# Processing Record 25 of Set 54 | koumac
# Processing Record 26 of Set 54 | ziarat
# Processing Record 27 of Set 54 | guanare
# Processing Record 28 of Set 54 | gumushane
# City not found. Skipping...
# Processing Record 29 of Set 54 | cassilandia
# Processing Record 30 of Set 54 | mazagao
# Processing Record 31 of Set 54 | bhim tal
# Processing Record 32 of Set 54 | riacho de santana
# Processing Record 33 of Set 54 | zaragoza
# Processing Record 34 of Set 54 | lagonoy
# Processing Record 35 of Set 54 | panguna
# Processing Record 36 of Set 54 | mutata
# Processing Record 37 of Set 54 | vaasa
# Processing Record 38 of Set 54 | delmenhorst
# Processing Record 39 of Set 54 | ishigaki
# Processing Record 40 of Set 54 | nova olinda do norte
# Processing Record 41 of Set 54 | leirvik
# Processing Record 42 of Set 54 | togur
# Processing Record 43 of Set 54 | kabinda
# Processing Record 44 of Set 54 | samastipur
# Processing Record 45 of Set 54 | balgazyn
# Processing Record 46 of Set 54 | kalisz
# Processing Record 47 of Set 54 | karakendzha
# City not found. Skipping...
# Processing Record 48 of Set 54 | stjordalshalsen
# Processing Record 49 of Set 54 | tlaxco
# Processing Record 50 of Set 54 | wahpeton
# Processing Record 1 of Set 55 | jinchengjiang
# City not found. Skipping...
# Processing Record 2 of Set 55 | bainbridge
# Processing Record 3 of Set 55 | colares
# Processing Record 4 of Set 55 | coro
# Processing Record 5 of Set 55 | astorga
# Processing Record 6 of Set 55 | magaria
# Processing Record 7 of Set 55 | kristiansand
# Processing Record 8 of Set 55 | chikhli
# Processing Record 9 of Set 55 | nogliki
# Processing Record 10 of Set 55 | urdoma
# Processing Record 11 of Set 55 | umiray
# Processing Record 12 of Set 55 | banff
# Processing Record 13 of Set 55 | yeltsovka
# City not found. Skipping...
# Processing Record 14 of Set 55 | mandurah
# Processing Record 15 of Set 55 | loukhi
# Processing Record 16 of Set 55 | araguaina
# Processing Record 17 of Set 55 | pandamatenga
# Processing Record 18 of Set 55 | betare oya
# Processing Record 19 of Set 55 | kerrville
# Processing Record 20 of Set 55 | bani walid
# Processing Record 21 of Set 55 | houlung
# City not found. Skipping...
# Processing Record 22 of Set 55 | richmond
# Processing Record 23 of Set 55 | parabel
# Processing Record 24 of Set 55 | veraval
# Processing Record 25 of Set 55 | grande-riviere
# City not found. Skipping...
# Processing Record 26 of Set 55 | kananga
# Processing Record 27 of Set 55 | ville-marie
# Processing Record 28 of Set 55 | beroroha
# Processing Record 29 of Set 55 | muli
# Processing Record 30 of Set 55 | paidha
# Processing Record 31 of Set 55 | grosseto
# Processing Record 32 of Set 55 | talas
# Processing Record 33 of Set 55 | paratinga
# Processing Record 34 of Set 55 | santa marta
# Processing Record 35 of Set 55 | minot
# Processing Record 36 of Set 55 | dabat
# Processing Record 37 of Set 55 | mildura
# Processing Record 38 of Set 55 | taldan
# Processing Record 39 of Set 55 | qandala
# Processing Record 40 of Set 55 | songadh
# Processing Record 41 of Set 55 | nikki
# Processing Record 42 of Set 55 | suez
# Processing Record 43 of Set 55 | quime
# Processing Record 44 of Set 55 | paithan
# Processing Record 45 of Set 55 | seekirchen
# City not found. Skipping...
# Processing Record 46 of Set 55 | rock sound
# Processing Record 47 of Set 55 | adre
# Processing Record 48 of Set 55 | hong gai
# Processing Record 49 of Set 55 | aurora
# Processing Record 50 of Set 55 | haibowan
# City not found. Skipping...
# Processing Record 1 of Set 56 | fiche
# Processing Record 2 of Set 56 | shar
# Processing Record 3 of Set 56 | novopavlovka
# Processing Record 4 of Set 56 | de land
# Processing Record 5 of Set 56 | kastamonu
# Processing Record 6 of Set 56 | jackson
# Processing Record 7 of Set 56 | arauca
# Processing Record 8 of Set 56 | schlitz
# Processing Record 9 of Set 56 | zheleznodorozhnyy
# Processing Record 10 of Set 56 | lichinga
# Processing Record 11 of Set 56 | jiayuguan
# Processing Record 12 of Set 56 | nuevo casas grandes
# Processing Record 13 of Set 56 | ghogha
# Processing Record 14 of Set 56 | sohag
# Processing Record 15 of Set 56 | vega de alatorre
# Processing Record 16 of Set 56 | chunskiy
# Processing Record 17 of Set 56 | les cayes
# Processing Record 18 of Set 56 | shelopugino
# Processing Record 19 of Set 56 | zima
# Processing Record 20 of Set 56 | rawah
# Processing Record 21 of Set 56 | thilogne
# City not found. Skipping...
# Processing Record 22 of Set 56 | ribe
# Processing Record 23 of Set 56 | mongoumba
# Processing Record 24 of Set 56 | adelaide
# Processing Record 25 of Set 56 | menomonie
# Processing Record 26 of Set 56 | tiebissou
# Processing Record 27 of Set 56 | noshiro
# Processing Record 28 of Set 56 | aruppukkottai
# Processing Record 29 of Set 56 | mocajuba
# Processing Record 30 of Set 56 | sasovo
# Processing Record 31 of Set 56 | raciborz
# Processing Record 32 of Set 56 | tromso
# Processing Record 33 of Set 56 | yangzhou
# Processing Record 34 of Set 56 | shymkent
# Processing Record 35 of Set 56 | lubao
# Processing Record 36 of Set 56 | dicabisagan
# Processing Record 37 of Set 56 | severodvinsk
# Processing Record 38 of Set 56 | samana
# Processing Record 39 of Set 56 | cruzilia
# Processing Record 40 of Set 56 | acopiara
# Processing Record 41 of Set 56 | krasnogvardeyskiy
# Processing Record 42 of Set 56 | bom jesus da lapa
# Processing Record 43 of Set 56 | wapi pathum
# Processing Record 44 of Set 56 | hvide sande
# Processing Record 45 of Set 56 | ortona
# Processing Record 46 of Set 56 | stoyba
# City not found. Skipping...
# Processing Record 47 of Set 56 | koshurnikovo
# Processing Record 48 of Set 56 | masvingo
# Processing Record 49 of Set 56 | macau
# Processing Record 50 of Set 56 | ivolginsk
# Processing Record 1 of Set 57 | shostka
# Processing Record 2 of Set 57 | fasa
# Processing Record 3 of Set 57 | graaff-reinet
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Tally the number of cities
len(city_data)
# Out:
# 2590

# %% [markdown]
# #### Step 05
# Add the data to a DF

# %%
#Convert the array of dictionaries to a pandas DF
city_data_df = pd.DataFrame(city_data)
city_data_df.index.name = 'City_ID'

#Check the DF
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Feels Like  Min Temp  Max Temp  \
# City_ID
# 0             Oranjemund -28.5500   16.4333       63.59     63.32     63.32
# 1             Chokurdakh  70.6333  147.9167      -54.87    -42.27    -42.27
# 2                  Lamar  33.6668  -95.5836       73.00     69.78     75.36
# 3         Saint-Philippe -21.3585   55.7679       77.00     75.22     76.59
# 4                 Kodiak  57.7900 -152.4072       21.58     27.91     27.91
# 5        Tirumullaivasal  11.2333   79.8333       80.15     78.67     78.67
# 6                  Bluff -46.6000  168.3333       49.03     51.80     51.80
# 7                 Matara   5.9485   80.5353       77.40     75.83     75.83
# 8                Kavieng  -2.5744  150.7967       89.02     82.09     82.09
# 9                 Castro -24.7911  -50.0119       68.52     68.41     68.41
#
#          Humidity  Cloudiness  Wind Speed Country       Description  \
# City_ID
# 0              90          52        6.51      NA     broken clouds
# 1             100          61        5.32      RU     broken clouds
# 2              78          90       18.41      US   overcast clouds
# 3              80          37       10.31      RE  scattered clouds
# 4              93          20        5.75      US        few clouds
# 5              83          25        6.31      IN  scattered clouds
# 6              50          89       11.52      NZ   overcast clouds
# 7              91          96        3.58      LK     moderate rain
# 8              80          96        7.85      PG   overcast clouds
# 9              76          92        9.93      BR   overcast clouds
#
#                         Date
# City_ID
# 0        2021-12-05 20:06:09
# 1        2021-12-05 20:06:10
# 2        2021-12-05 20:06:10
# 3        2021-12-05 20:06:10
# 4        2021-12-05 20:06:11
# 5        2021-12-05 20:06:11
# 6        2021-12-05 20:06:11
# 7        2021-12-05 20:06:12
# 8        2021-12-05 20:06:12
# 9        2021-12-05 20:06:12

# %% [markdown]
# #### Step 06
# Export the DF as a csv file [WeatherPy_Database.csv]

# %%
#Save the DF
city_data_df.to_csv('WeatherPy_Database.csv', index_label='City_ID')

#Check the DF
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Feels Like  Min Temp  Max Temp  \
# City_ID
# 0             Oranjemund -28.5500   16.4333       63.59     63.32     63.32
# 1             Chokurdakh  70.6333  147.9167      -54.87    -42.27    -42.27
# 2                  Lamar  33.6668  -95.5836       73.00     69.78     75.36
# 3         Saint-Philippe -21.3585   55.7679       77.00     75.22     76.59
# 4                 Kodiak  57.7900 -152.4072       21.58     27.91     27.91
# 5        Tirumullaivasal  11.2333   79.8333       80.15     78.67     78.67
# 6                  Bluff -46.6000  168.3333       49.03     51.80     51.80
# 7                 Matara   5.9485   80.5353       77.40     75.83     75.83
# 8                Kavieng  -2.5744  150.7967       89.02     82.09     82.09
# 9                 Castro -24.7911  -50.0119       68.52     68.41     68.41
#
#          Humidity  Cloudiness  Wind Speed Country       Description  \
# City_ID
# 0              90          52        6.51      NA     broken clouds
# 1             100          61        5.32      RU     broken clouds
# 2              78          90       18.41      US   overcast clouds
# 3              80          37       10.31      RE  scattered clouds
# 4              93          20        5.75      US        few clouds
# 5              83          25        6.31      IN  scattered clouds
# 6              50          89       11.52      NZ   overcast clouds
# 7              91          96        3.58      LK     moderate rain
# 8              80          96        7.85      PG   overcast clouds
# 9              76          92        9.93      BR   overcast clouds
#
#                         Date
# City_ID
# 0        2021-12-05 20:06:09
# 1        2021-12-05 20:06:10
# 2        2021-12-05 20:06:10
# 3        2021-12-05 20:06:10
# 4        2021-12-05 20:06:11
# 5        2021-12-05 20:06:11
# 6        2021-12-05 20:06:11
# 7        2021-12-05 20:06:12
# 8        2021-12-05 20:06:12
# 9        2021-12-05 20:06:12
