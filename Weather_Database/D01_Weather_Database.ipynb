# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data.

# %% [markdown]
# 1. Create a set of 2,000 random latitudes / longitudes
# 2. Get the nearest city using citipy
# 3. Make an API call with OpenWeatherMap
# 4. Retrieve the following info:
#     - Latitude / longitude
#     - Maximum temperature
#     - % Humidity
#     - % Cloudiness
#     - Wind speed
#     - Weather description
# 5. Add the data to a DF
# 6. Export the DF as a csv file, saved as WeatherPy_Database.csv

# %% [markdown]
# #### Step 01
# Create a set of (at least) 2,000 random latitudes / longitudes

# %%
# Add Matplotlib inline magic command
# %matplotlib inline

#Import dependencies, libaries, & build the base URL
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

import requests

import time
from datetime import datetime

#Import the API key
from config import weather_api_key

#Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# #### Step 02
# Get the nearest city using the citipy module

# %%
#Generate a set of random latitude and logitude combos ()
lats = np.random.uniform(low=-90.000, high=90.000, size=14000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=14000)
lat_lngs = zip(lats, lngs)

#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

#Create a list to hold the cities
cities = []

#Identify the nearest city for each lat/long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 2796

# %% [markdown]
# #### Step 03
# Make an API call using OpenWeatherMap

# %% [markdown]
# #### Step 04
# Retrieve weather info including lat/long, max temp, % humidity, % cloudiness, windspeed, & weather description

# %%
#Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

#Loop through the cities in the list.
for i, city in enumerate(cities):
    
    #Group the cities in sets of 50 for logging
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log the URL, record, set numbers, and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count
    record_count += 1
    
    #Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        #Parse the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_feels = city_weather['main']['feels_like']
        city_min_temp = city_weather['main']['temp_min']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        #Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        
        #Append the city info into city_data list
        city_data.append({"City": city.title(),
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Feels Like': city_feels,
                          'Min Temp': city_min_temp,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Country': city_country,
                          'Current Description': city_description,
                          'Date': city_date})
    #If there is an error, skip the city
    except:
        print("City not found. Skipping...")
        continue

#Indicate Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lagoa
# Processing Record 2 of Set 1 | yarada
# Processing Record 3 of Set 1 | marienburg
# Processing Record 4 of Set 1 | havelock
# Processing Record 5 of Set 1 | provideniya
# Processing Record 6 of Set 1 | tasiilaq
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | behbahan
# Processing Record 10 of Set 1 | norman wells
# Processing Record 11 of Set 1 | ust-kulom
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | rundu
# Processing Record 14 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | imeni poliny osipenko
# Processing Record 19 of Set 1 | nalut
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | airai
# Processing Record 22 of Set 1 | lundazi
# Processing Record 23 of Set 1 | geraldton
# Processing Record 24 of Set 1 | karpathos
# Processing Record 25 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 26 of Set 1 | dingle
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | humaita
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | lompoc
# Processing Record 31 of Set 1 | baoding
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | marawi
# Processing Record 34 of Set 1 | odweyne
# Processing Record 35 of Set 1 | emirdag
# Processing Record 36 of Set 1 | imbituba
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | naze
# Processing Record 40 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 1 | fortuna
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | asfi
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | aksarka
# Processing Record 48 of Set 1 | bathsheba
# Processing Record 49 of Set 1 | paamiut
# Processing Record 50 of Set 1 | taber
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | tateyama
# Processing Record 3 of Set 2 | quatre cocos
# Processing Record 4 of Set 2 | cidreira
# Processing Record 5 of Set 2 | pevek
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | iqaluit
# Processing Record 8 of Set 2 | ribeira grande
# Processing Record 9 of Set 2 | katsuura
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | kendari
# Processing Record 12 of Set 2 | zhuhai
# Processing Record 13 of Set 2 | myitkyina
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | piacabucu
# Processing Record 18 of Set 2 | bethel
# Processing Record 19 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 2 | teknaf
# Processing Record 21 of Set 2 | dunedin
# Processing Record 22 of Set 2 | vytegra
# Processing Record 23 of Set 2 | bria
# Processing Record 24 of Set 2 | mokhsogollokh
# Processing Record 25 of Set 2 | torbay
# Processing Record 26 of Set 2 | souillac
# Processing Record 27 of Set 2 | bambous virieux
# Processing Record 28 of Set 2 | viedma
# Processing Record 29 of Set 2 | albany
# Processing Record 30 of Set 2 | broome
# Processing Record 31 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 2 | nouakchott
# Processing Record 33 of Set 2 | gladstone
# Processing Record 34 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 35 of Set 2 | belaya gora
# Processing Record 36 of Set 2 | emerald
# Processing Record 37 of Set 2 | abu dhabi
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | hermanus
# Processing Record 41 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | castro
# Processing Record 44 of Set 2 | atikokan
# Processing Record 45 of Set 2 | sao joao da barra
# Processing Record 46 of Set 2 | manhattan
# Processing Record 47 of Set 2 | upata
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | puerto del rosario
# Processing Record 50 of Set 2 | ygatimi
# Processing Record 1 of Set 3 | alihe
# Processing Record 2 of Set 3 | sinnamary
# Processing Record 3 of Set 3 | new norfolk
# Processing Record 4 of Set 3 | elko
# Processing Record 5 of Set 3 | hithadhoo
# Processing Record 6 of Set 3 | bereda
# Processing Record 7 of Set 3 | abashiri
# Processing Record 8 of Set 3 | mengcheng
# Processing Record 9 of Set 3 | punta arenas
# Processing Record 10 of Set 3 | lorengau
# Processing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 3 | sault sainte marie
# Processing Record 13 of Set 3 | okhotsk
# Processing Record 14 of Set 3 | miraflores
# Processing Record 15 of Set 3 | mao
# Processing Record 16 of Set 3 | sisimiut
# Processing Record 17 of Set 3 | killybegs
# Processing Record 18 of Set 3 | otjiwarongo
# Processing Record 19 of Set 3 | wanning
# Processing Record 20 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 3 | kutum
# Processing Record 22 of Set 3 | deputatskiy
# Processing Record 23 of Set 3 | yithion
# City not found. Skipping...
# Processing Record 24 of Set 3 | shamkhal
# Processing Record 25 of Set 3 | clyde river
# Processing Record 26 of Set 3 | bengkulu
# Processing Record 27 of Set 3 | vikhorevka
# Processing Record 28 of Set 3 | cayenne
# Processing Record 29 of Set 3 | cape town
# Processing Record 30 of Set 3 | busselton
# Processing Record 31 of Set 3 | ponta do sol
# Processing Record 32 of Set 3 | niamey
# Processing Record 33 of Set 3 | jamestown
# Processing Record 34 of Set 3 | adrar
# Processing Record 35 of Set 3 | mancora
# Processing Record 36 of Set 3 | shingu
# Processing Record 37 of Set 3 | punta alta
# Processing Record 38 of Set 3 | tulun
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | atuona
# Processing Record 41 of Set 3 | luderitz
# Processing Record 42 of Set 3 | amahai
# Processing Record 43 of Set 3 | alyangula
# Processing Record 44 of Set 3 | nizhniy kuranakh
# Processing Record 45 of Set 3 | ballina
# Processing Record 46 of Set 3 | klaksvik
# Processing Record 47 of Set 3 | kavieng
# Processing Record 48 of Set 3 | mayo
# Processing Record 49 of Set 3 | sydney
# Processing Record 50 of Set 3 | angra
# City not found. Skipping...
# Processing Record 1 of Set 4 | upernavik
# Processing Record 2 of Set 4 | parrita
# Processing Record 3 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 4 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | cabo san lucas
# Processing Record 6 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 4 | hambantota
# Processing Record 8 of Set 4 | zabol
# Processing Record 9 of Set 4 | farrukhnagar
# Processing Record 10 of Set 4 | puerto leguizamo
# Processing Record 11 of Set 4 | kodiak
# Processing Record 12 of Set 4 | kudahuvadhoo
# Processing Record 13 of Set 4 | noyabrsk
# Processing Record 14 of Set 4 | kruisfontein
# Processing Record 15 of Set 4 | dikson
# Processing Record 16 of Set 4 | kavaratti
# Processing Record 17 of Set 4 | port elizabeth
# Processing Record 18 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 4 | warrnambool
# Processing Record 20 of Set 4 | malaba
# Processing Record 21 of Set 4 | poum
# Processing Record 22 of Set 4 | te anau
# Processing Record 23 of Set 4 | montijo
# Processing Record 24 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 4 | mariana
# Processing Record 26 of Set 4 | ushtobe
# Processing Record 27 of Set 4 | rosa zarate
# Processing Record 28 of Set 4 | saldanha
# Processing Record 29 of Set 4 | moree
# Processing Record 30 of Set 4 | quang ngai
# Processing Record 31 of Set 4 | bandar-e lengeh
# Processing Record 32 of Set 4 | khatanga
# Processing Record 33 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 4 | xiaoshi
# Processing Record 35 of Set 4 | concepcion del oro
# Processing Record 36 of Set 4 | bonavista
# Processing Record 37 of Set 4 | yulara
# Processing Record 38 of Set 4 | zhuanghe
# Processing Record 39 of Set 4 | kedrovyy
# Processing Record 40 of Set 4 | juneau
# Processing Record 41 of Set 4 | montepuez
# Processing Record 42 of Set 4 | ambulu
# Processing Record 43 of Set 4 | san patricio
# Processing Record 44 of Set 4 | yagodnoye
# Processing Record 45 of Set 4 | palana
# Processing Record 46 of Set 4 | kahului
# Processing Record 47 of Set 4 | roblin
# Processing Record 48 of Set 4 | longyearbyen
# Processing Record 49 of Set 4 | coihaique
# Processing Record 50 of Set 4 | doha
# Processing Record 1 of Set 5 | saint-francois
# Processing Record 2 of Set 5 | verkhnevilyuysk
# Processing Record 3 of Set 5 | grand-lahou
# Processing Record 4 of Set 5 | japura
# Processing Record 5 of Set 5 | nome
# Processing Record 6 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 5 | saint-joseph
# Processing Record 8 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 9 of Set 5 | guerrero negro
# Processing Record 10 of Set 5 | honningsvag
# Processing Record 11 of Set 5 | saint-augustin
# Processing Record 12 of Set 5 | kipushi
# Processing Record 13 of Set 5 | codrington
# Processing Record 14 of Set 5 | pochutla
# Processing Record 15 of Set 5 | douglas
# Processing Record 16 of Set 5 | khani
# Processing Record 17 of Set 5 | borovoy
# Processing Record 18 of Set 5 | shibganj
# Processing Record 19 of Set 5 | aranos
# Processing Record 20 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 21 of Set 5 | teguldet
# Processing Record 22 of Set 5 | avera
# Processing Record 23 of Set 5 | huilong
# Processing Record 24 of Set 5 | esperance
# Processing Record 25 of Set 5 | reconquista
# Processing Record 26 of Set 5 | tarko-sale
# Processing Record 27 of Set 5 | kawalu
# Processing Record 28 of Set 5 | georgetown
# Processing Record 29 of Set 5 | vao
# Processing Record 30 of Set 5 | nikel
# Processing Record 31 of Set 5 | hasaki
# Processing Record 32 of Set 5 | cherskiy
# Processing Record 33 of Set 5 | chimore
# Processing Record 34 of Set 5 | nicoya
# Processing Record 35 of Set 5 | arman
# Processing Record 36 of Set 5 | scalloway
# City not found. Skipping...
# Processing Record 37 of Set 5 | socorro
# Processing Record 38 of Set 5 | mastic beach
# Processing Record 39 of Set 5 | riyadh
# Processing Record 40 of Set 5 | tessalit
# Processing Record 41 of Set 5 | la romana
# Processing Record 42 of Set 5 | concordia
# Processing Record 43 of Set 5 | tsaratanana
# Processing Record 44 of Set 5 | seoul
# Processing Record 45 of Set 5 | cockburn town
# Processing Record 46 of Set 5 | leningradskiy
# Processing Record 47 of Set 5 | coquimbo
# Processing Record 48 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 49 of Set 5 | oakdale
# Processing Record 50 of Set 5 | panguna
# Processing Record 1 of Set 6 | oum hadjer
# Processing Record 2 of Set 6 | houma
# Processing Record 3 of Set 6 | bubaque
# Processing Record 4 of Set 6 | hofn
# Processing Record 5 of Set 6 | dudinka
# Processing Record 6 of Set 6 | narsaq
# Processing Record 7 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 6 | faanui
# Processing Record 9 of Set 6 | pozo colorado
# Processing Record 10 of Set 6 | freeport
# Processing Record 11 of Set 6 | buchanan
# Processing Record 12 of Set 6 | ilulissat
# Processing Record 13 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 6 | mitsamiouli
# Processing Record 15 of Set 6 | ostrovnoy
# Processing Record 16 of Set 6 | srednekolymsk
# Processing Record 17 of Set 6 | sao filipe
# Processing Record 18 of Set 6 | kerman
# Processing Record 19 of Set 6 | padang
# Processing Record 20 of Set 6 | maloy
# Processing Record 21 of Set 6 | cairns
# Processing Record 22 of Set 6 | nanortalik
# Processing Record 23 of Set 6 | katherine
# Processing Record 24 of Set 6 | moose factory
# Processing Record 25 of Set 6 | saskylakh
# Processing Record 26 of Set 6 | teguise
# Processing Record 27 of Set 6 | shestakovo
# Processing Record 28 of Set 6 | rio grande
# Processing Record 29 of Set 6 | sierpc
# Processing Record 30 of Set 6 | asau
# Processing Record 31 of Set 6 | praia da vitoria
# Processing Record 32 of Set 6 | morristown
# Processing Record 33 of Set 6 | port lincoln
# Processing Record 34 of Set 6 | mandera
# Processing Record 35 of Set 6 | mahibadhoo
# Processing Record 36 of Set 6 | bridlington
# Processing Record 37 of Set 6 | capiibary
# Processing Record 38 of Set 6 | katobu
# Processing Record 39 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 6 | tamworth
# Processing Record 41 of Set 6 | sujiatun
# Processing Record 42 of Set 6 | tual
# Processing Record 43 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 6 | honiara
# Processing Record 45 of Set 6 | fort nelson
# Processing Record 46 of Set 6 | batagay-alyta
# Processing Record 47 of Set 6 | narasannapeta
# Processing Record 48 of Set 6 | san cristobal
# Processing Record 49 of Set 6 | nuuk
# Processing Record 50 of Set 6 | nantucket
# Processing Record 1 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 7 | mecca
# Processing Record 3 of Set 7 | monrovia
# Processing Record 4 of Set 7 | calvinia
# Processing Record 5 of Set 7 | kaitangata
# Processing Record 6 of Set 7 | nanakuli
# Processing Record 7 of Set 7 | namatanai
# Processing Record 8 of Set 7 | waingapu
# Processing Record 9 of Set 7 | ancud
# Processing Record 10 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 7 | moen
# Processing Record 12 of Set 7 | severo-kurilsk
# Processing Record 13 of Set 7 | port macquarie
# Processing Record 14 of Set 7 | santa cruz de tenerife
# Processing Record 15 of Set 7 | goundam
# Processing Record 16 of Set 7 | glendive
# Processing Record 17 of Set 7 | payson
# Processing Record 18 of Set 7 | uyuni
# Processing Record 19 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 20 of Set 7 | sitka
# Processing Record 21 of Set 7 | kailua
# Processing Record 22 of Set 7 | victoria
# Processing Record 23 of Set 7 | sabang
# Processing Record 24 of Set 7 | redcar
# Processing Record 25 of Set 7 | prince rupert
# Processing Record 26 of Set 7 | walvis bay
# Processing Record 27 of Set 7 | colesberg
# Processing Record 28 of Set 7 | emborion
# Processing Record 29 of Set 7 | yamada
# Processing Record 30 of Set 7 | norton
# Processing Record 31 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 32 of Set 7 | chokurdakh
# Processing Record 33 of Set 7 | biak
# Processing Record 34 of Set 7 | hailey
# Processing Record 35 of Set 7 | la capilla
# Processing Record 36 of Set 7 | tuatapere
# Processing Record 37 of Set 7 | anori
# Processing Record 38 of Set 7 | tezu
# Processing Record 39 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 7 | nhulunbuy
# Processing Record 41 of Set 7 | pompeia
# Processing Record 42 of Set 7 | bestobe
# Processing Record 43 of Set 7 | yumen
# Processing Record 44 of Set 7 | davidson
# Processing Record 45 of Set 7 | khandwa
# Processing Record 46 of Set 7 | dongzhen
# Processing Record 47 of Set 7 | marystown
# Processing Record 48 of Set 7 | los llanos de aridane
# Processing Record 49 of Set 7 | isangel
# Processing Record 50 of Set 7 | saint-pierre
# Processing Record 1 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 8 | hobyo
# Processing Record 3 of Set 8 | meulaboh
# Processing Record 4 of Set 8 | xai-xai
# Processing Record 5 of Set 8 | trairi
# Processing Record 6 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 8 | hervey bay
# Processing Record 8 of Set 8 | pombas
# Processing Record 9 of Set 8 | bitung
# Processing Record 10 of Set 8 | lahore
# Processing Record 11 of Set 8 | port hardy
# Processing Record 12 of Set 8 | okakarara
# Processing Record 13 of Set 8 | chokwe
# Processing Record 14 of Set 8 | pacific grove
# Processing Record 15 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 8 | tela
# Processing Record 17 of Set 8 | lodja
# Processing Record 18 of Set 8 | boffa
# Processing Record 19 of Set 8 | sur
# Processing Record 20 of Set 8 | bada
# Processing Record 21 of Set 8 | acapulco
# Processing Record 22 of Set 8 | jumla
# Processing Record 23 of Set 8 | carutapera
# Processing Record 24 of Set 8 | portland
# Processing Record 25 of Set 8 | mahebourg
# Processing Record 26 of Set 8 | vadso
# Processing Record 27 of Set 8 | likasi
# Processing Record 28 of Set 8 | kushiro
# Processing Record 29 of Set 8 | tsuyama
# Processing Record 30 of Set 8 | imeni zhelyabova
# Processing Record 31 of Set 8 | atambua
# Processing Record 32 of Set 8 | grimmen
# Processing Record 33 of Set 8 | northam
# Processing Record 34 of Set 8 | zhigansk
# Processing Record 35 of Set 8 | yar-sale
# Processing Record 36 of Set 8 | polessk
# Processing Record 37 of Set 8 | grindavik
# Processing Record 38 of Set 8 | manta
# Processing Record 39 of Set 8 | vuyyuru
# Processing Record 40 of Set 8 | saint-paul
# Processing Record 41 of Set 8 | koulikoro
# Processing Record 42 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 8 | xanten
# Processing Record 44 of Set 8 | tautira
# Processing Record 45 of Set 8 | kupang
# Processing Record 46 of Set 8 | caxito
# Processing Record 47 of Set 8 | touros
# Processing Record 48 of Set 8 | hirado
# Processing Record 49 of Set 8 | damghan
# Processing Record 50 of Set 8 | constitucion
# Processing Record 1 of Set 9 | rong kwang
# Processing Record 2 of Set 9 | allapalli
# Processing Record 3 of Set 9 | ponta delgada
# Processing Record 4 of Set 9 | tsuruoka
# Processing Record 5 of Set 9 | tura
# Processing Record 6 of Set 9 | labytnangi
# Processing Record 7 of Set 9 | hamilton
# Processing Record 8 of Set 9 | puerto narino
# Processing Record 9 of Set 9 | sapa
# Processing Record 10 of Set 9 | kuytun
# Processing Record 11 of Set 9 | vardo
# Processing Record 12 of Set 9 | keti bandar
# Processing Record 13 of Set 9 | dakoro
# Processing Record 14 of Set 9 | ternate
# Processing Record 15 of Set 9 | gouyave
# Processing Record 16 of Set 9 | qaqortoq
# Processing Record 17 of Set 9 | ogaminana
# Processing Record 18 of Set 9 | saku
# Processing Record 19 of Set 9 | coahuayana
# Processing Record 20 of Set 9 | rio cuarto
# Processing Record 21 of Set 9 | berlevag
# Processing Record 22 of Set 9 | manggar
# Processing Record 23 of Set 9 | minab
# Processing Record 24 of Set 9 | maldonado
# Processing Record 25 of Set 9 | chuy
# Processing Record 26 of Set 9 | gualeguaychu
# Processing Record 27 of Set 9 | brae
# Processing Record 28 of Set 9 | tsumeb
# Processing Record 29 of Set 9 | davila
# Processing Record 30 of Set 9 | djibo
# Processing Record 31 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 32 of Set 9 | laguna
# Processing Record 33 of Set 9 | magdalena
# Processing Record 34 of Set 9 | rafsanjan
# Processing Record 35 of Set 9 | aquiraz
# Processing Record 36 of Set 9 | sao sebastiao
# Processing Record 37 of Set 9 | amapa
# Processing Record 38 of Set 9 | ginir
# Processing Record 39 of Set 9 | nurota
# Processing Record 40 of Set 9 | saint george
# Processing Record 41 of Set 9 | dunmore town
# Processing Record 42 of Set 9 | dhidhdhoo
# Processing Record 43 of Set 9 | opobo
# City not found. Skipping...
# Processing Record 44 of Set 9 | velim
# Processing Record 45 of Set 9 | comodoro rivadavia
# Processing Record 46 of Set 9 | malanville
# Processing Record 47 of Set 9 | aykhal
# Processing Record 48 of Set 9 | kargil
# Processing Record 49 of Set 9 | isabela
# Processing Record 50 of Set 9 | wukari
# Processing Record 1 of Set 10 | aqtobe
# Processing Record 2 of Set 10 | mantua
# Processing Record 3 of Set 10 | almeirim
# Processing Record 4 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 10 | aitape
# Processing Record 6 of Set 10 | san policarpo
# Processing Record 7 of Set 10 | penzance
# Processing Record 8 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 10 | galbshtadt
# Processing Record 10 of Set 10 | batagay
# Processing Record 11 of Set 10 | alakurtti
# Processing Record 12 of Set 10 | fare
# Processing Record 13 of Set 10 | fairbanks
# Processing Record 14 of Set 10 | kaeo
# Processing Record 15 of Set 10 | salinopolis
# Processing Record 16 of Set 10 | namibe
# Processing Record 17 of Set 10 | romitan
# Processing Record 18 of Set 10 | nuevo progreso
# Processing Record 19 of Set 10 | labuhan
# Processing Record 20 of Set 10 | chumikan
# Processing Record 21 of Set 10 | basarabeasca
# Processing Record 22 of Set 10 | mildura
# Processing Record 23 of Set 10 | charlestown
# Processing Record 24 of Set 10 | teluknaga
# Processing Record 25 of Set 10 | alice springs
# Processing Record 26 of Set 10 | soubre
# Processing Record 27 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 28 of Set 10 | tabas
# Processing Record 29 of Set 10 | sadon
# Processing Record 30 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 31 of Set 10 | monticello
# Processing Record 32 of Set 10 | krasnoselkup
# Processing Record 33 of Set 10 | burica
# City not found. Skipping...
# Processing Record 34 of Set 10 | buala
# Processing Record 35 of Set 10 | biu
# Processing Record 36 of Set 10 | nargana
# Processing Record 37 of Set 10 | erenhot
# Processing Record 38 of Set 10 | florianopolis
# Processing Record 39 of Set 10 | adwa
# Processing Record 40 of Set 10 | thohoyandou
# Processing Record 41 of Set 10 | neuquen
# Processing Record 42 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 10 | alofi
# Processing Record 44 of Set 10 | lata
# Processing Record 45 of Set 10 | mazatlan
# Processing Record 46 of Set 10 | key west
# Processing Record 47 of Set 10 | vostok
# Processing Record 48 of Set 10 | tucurui
# Processing Record 49 of Set 10 | evensk
# Processing Record 50 of Set 10 | atasu
# Processing Record 1 of Set 11 | panama city
# Processing Record 2 of Set 11 | alanya
# Processing Record 3 of Set 11 | luena
# Processing Record 4 of Set 11 | glens falls
# Processing Record 5 of Set 11 | valle de allende
# Processing Record 6 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 7 of Set 11 | flinders
# Processing Record 8 of Set 11 | pipar
# Processing Record 9 of Set 11 | dalbandin
# Processing Record 10 of Set 11 | puerto ayacucho
# Processing Record 11 of Set 11 | manaure
# Processing Record 12 of Set 11 | lagos
# Processing Record 13 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 11 | mae sot
# Processing Record 15 of Set 11 | college
# Processing Record 16 of Set 11 | kopayhorod
# Processing Record 17 of Set 11 | kombissiri
# Processing Record 18 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 11 | khammam
# Processing Record 20 of Set 11 | manbij
# Processing Record 21 of Set 11 | nouadhibou
# Processing Record 22 of Set 11 | ugoofaaru
# Processing Record 23 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 11 | dimitrovgrad
# Processing Record 26 of Set 11 | lavrentiya
# Processing Record 27 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 11 | port-gentil
# Processing Record 30 of Set 11 | rehoboth
# Processing Record 31 of Set 11 | boa vista
# Processing Record 32 of Set 11 | oktyabrskoye
# Processing Record 33 of Set 11 | pahrump
# Processing Record 34 of Set 11 | joshimath
# Processing Record 35 of Set 11 | malayal
# Processing Record 36 of Set 11 | aswan
# Processing Record 37 of Set 11 | mackenzie
# Processing Record 38 of Set 11 | awjilah
# Processing Record 39 of Set 11 | tankhoy
# Processing Record 40 of Set 11 | kolpashevo
# Processing Record 41 of Set 11 | hovd
# Processing Record 42 of Set 11 | muros
# Processing Record 43 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 11 | barcelona
# Processing Record 45 of Set 11 | luwuk
# Processing Record 46 of Set 11 | biloela
# Processing Record 47 of Set 11 | paucartambo
# City not found. Skipping...
# Processing Record 48 of Set 11 | venado tuerto
# Processing Record 49 of Set 11 | chamba
# Processing Record 50 of Set 11 | nueva loja
# Processing Record 1 of Set 12 | aden
# Processing Record 2 of Set 12 | ulaangom
# Processing Record 3 of Set 12 | sragen
# Processing Record 4 of Set 12 | belmonte
# Processing Record 5 of Set 12 | tilichiki
# Processing Record 6 of Set 12 | kasongo-lunda
# Processing Record 7 of Set 12 | manacapuru
# Processing Record 8 of Set 12 | ponta pora
# Processing Record 9 of Set 12 | baijiantan
# Processing Record 10 of Set 12 | la ronge
# Processing Record 11 of Set 12 | kenai
# Processing Record 12 of Set 12 | sarangani
# Processing Record 13 of Set 12 | lovozero
# Processing Record 14 of Set 12 | ketchikan
# Processing Record 15 of Set 12 | sobolevo
# Processing Record 16 of Set 12 | gamba
# Processing Record 17 of Set 12 | swan hill
# Processing Record 18 of Set 12 | verkhniy tagil
# Processing Record 19 of Set 12 | bajil
# Processing Record 20 of Set 12 | deh rawud
# City not found. Skipping...
# Processing Record 21 of Set 12 | manjacaze
# Processing Record 22 of Set 12 | pacifica
# Processing Record 23 of Set 12 | aneho
# Processing Record 24 of Set 12 | bima
# Processing Record 25 of Set 12 | porto torres
# Processing Record 26 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 27 of Set 12 | lucea
# Processing Record 28 of Set 12 | itoman
# Processing Record 29 of Set 12 | tocache
# Processing Record 30 of Set 12 | vallenar
# Processing Record 31 of Set 12 | campbell river
# Processing Record 32 of Set 12 | mehamn
# Processing Record 33 of Set 12 | sosua
# Processing Record 34 of Set 12 | svetlogorsk
# Processing Record 35 of Set 12 | north platte
# Processing Record 36 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 37 of Set 12 | waterfoot
# Processing Record 38 of Set 12 | malakal
# Processing Record 39 of Set 12 | vanimo
# Processing Record 40 of Set 12 | belyy gorodok
# Processing Record 41 of Set 12 | porto velho
# Processing Record 42 of Set 12 | mwanza
# Processing Record 43 of Set 12 | pemangkat
# Processing Record 44 of Set 12 | tomatlan
# Processing Record 45 of Set 12 | half moon bay
# Processing Record 46 of Set 12 | yefimovskiy
# City not found. Skipping...
# Processing Record 47 of Set 12 | liverpool
# Processing Record 48 of Set 12 | kyren
# Processing Record 49 of Set 12 | petauke
# Processing Record 50 of Set 12 | chapais
# Processing Record 1 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 13 | teya
# Processing Record 3 of Set 13 | robertsport
# Processing Record 4 of Set 13 | mount gambier
# Processing Record 5 of Set 13 | rio gallegos
# Processing Record 6 of Set 13 | safakulevo
# Processing Record 7 of Set 13 | shakhovskaya
# Processing Record 8 of Set 13 | yangambi
# Processing Record 9 of Set 13 | yelizovo
# Processing Record 10 of Set 13 | moindou
# Processing Record 11 of Set 13 | mount isa
# Processing Record 12 of Set 13 | jizan
# Processing Record 13 of Set 13 | camacupa
# Processing Record 14 of Set 13 | danane
# Processing Record 15 of Set 13 | flin flon
# Processing Record 16 of Set 13 | yarkovo
# Processing Record 17 of Set 13 | karasjok
# Processing Record 18 of Set 13 | dukat
# Processing Record 19 of Set 13 | whakatane
# Processing Record 20 of Set 13 | margate
# Processing Record 21 of Set 13 | alta floresta
# Processing Record 22 of Set 13 | trincomalee
# Processing Record 23 of Set 13 | lensk
# Processing Record 24 of Set 13 | usoke
# Processing Record 25 of Set 13 | vila franca do campo
# Processing Record 26 of Set 13 | ios
# Processing Record 27 of Set 13 | curug
# Processing Record 28 of Set 13 | henties bay
# Processing Record 29 of Set 13 | sao lourenco do sul
# Processing Record 30 of Set 13 | wick
# Processing Record 31 of Set 13 | harnosand
# Processing Record 32 of Set 13 | saint anthony
# Processing Record 33 of Set 13 | bandarbeyla
# Processing Record 34 of Set 13 | bunol
# Processing Record 35 of Set 13 | zaraza
# Processing Record 36 of Set 13 | ucluelet
# Processing Record 37 of Set 13 | kokopo
# Processing Record 38 of Set 13 | maues
# Processing Record 39 of Set 13 | puerto escondido
# Processing Record 40 of Set 13 | janakpur
# Processing Record 41 of Set 13 | starosubkhangulovo
# Processing Record 42 of Set 13 | komsomolskiy
# Processing Record 43 of Set 13 | at-bashi
# Processing Record 44 of Set 13 | verkhoyansk
# Processing Record 45 of Set 13 | newport
# Processing Record 46 of Set 13 | pangnirtung
# Processing Record 47 of Set 13 | guane
# Processing Record 48 of Set 13 | eureka
# Processing Record 49 of Set 13 | novopskov
# Processing Record 50 of Set 13 | saurimo
# Processing Record 1 of Set 14 | ormara
# Processing Record 2 of Set 14 | taoudenni
# Processing Record 3 of Set 14 | nemuro
# Processing Record 4 of Set 14 | cuamba
# Processing Record 5 of Set 14 | beloha
# Processing Record 6 of Set 14 | mizan teferi
# Processing Record 7 of Set 14 | blagoyevo
# Processing Record 8 of Set 14 | tanga
# Processing Record 9 of Set 14 | san esteban
# Processing Record 10 of Set 14 | hirara
# Processing Record 11 of Set 14 | witrivier
# City not found. Skipping...
# Processing Record 12 of Set 14 | grand gaube
# Processing Record 13 of Set 14 | castro-urdiales
# Processing Record 14 of Set 14 | the pas
# Processing Record 15 of Set 14 | lazaro cardenas
# Processing Record 16 of Set 14 | taywarah
# Processing Record 17 of Set 14 | lexington
# Processing Record 18 of Set 14 | luanda
# Processing Record 19 of Set 14 | mocuba
# Processing Record 20 of Set 14 | togur
# Processing Record 21 of Set 14 | tonantins
# Processing Record 22 of Set 14 | yarmouth
# Processing Record 23 of Set 14 | ambilobe
# Processing Record 24 of Set 14 | along
# Processing Record 25 of Set 14 | adjumani
# Processing Record 26 of Set 14 | rawson
# Processing Record 27 of Set 14 | hun
# Processing Record 28 of Set 14 | port blair
# Processing Record 29 of Set 14 | la libertad
# Processing Record 30 of Set 14 | longonjo
# Processing Record 31 of Set 14 | oktyabrskiy
# Processing Record 32 of Set 14 | galveston
# Processing Record 33 of Set 14 | tommot
# Processing Record 34 of Set 14 | mattru
# Processing Record 35 of Set 14 | orocue
# Processing Record 36 of Set 14 | bandarban
# Processing Record 37 of Set 14 | san alberto
# Processing Record 38 of Set 14 | makakilo city
# Processing Record 39 of Set 14 | gat
# Processing Record 40 of Set 14 | dewas
# Processing Record 41 of Set 14 | chicama
# Processing Record 42 of Set 14 | syamzha
# Processing Record 43 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 44 of Set 14 | verkh-suetka
# Processing Record 45 of Set 14 | gorontalo
# Processing Record 46 of Set 14 | kindu
# Processing Record 47 of Set 14 | rokytne
# Processing Record 48 of Set 14 | umba
# Processing Record 49 of Set 14 | talnakh
# Processing Record 50 of Set 14 | phuthaditjhaba
# Processing Record 1 of Set 15 | darab
# Processing Record 2 of Set 15 | port hedland
# Processing Record 3 of Set 15 | gambela
# Processing Record 4 of Set 15 | cedar city
# Processing Record 5 of Set 15 | tiruvottiyur
# City not found. Skipping...
# Processing Record 6 of Set 15 | nefteyugansk
# Processing Record 7 of Set 15 | gore
# Processing Record 8 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 9 of Set 15 | meschede
# Processing Record 10 of Set 15 | andenes
# Processing Record 11 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 12 of Set 15 | santa rosa
# Processing Record 13 of Set 15 | santa fe
# Processing Record 14 of Set 15 | albury
# Processing Record 15 of Set 15 | jiuquan
# Processing Record 16 of Set 15 | havre-saint-pierre
# Processing Record 17 of Set 15 | maceio
# Processing Record 18 of Set 15 | husavik
# Processing Record 19 of Set 15 | muswellbrook
# Processing Record 20 of Set 15 | noumea
# Processing Record 21 of Set 15 | nagorsk
# Processing Record 22 of Set 15 | karasburg
# Processing Record 23 of Set 15 | yangjiang
# Processing Record 24 of Set 15 | najran
# Processing Record 25 of Set 15 | sturgis
# Processing Record 26 of Set 15 | loa janan
# Processing Record 27 of Set 15 | riachao
# Processing Record 28 of Set 15 | halifax
# Processing Record 29 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 15 | svetlaya
# Processing Record 31 of Set 15 | senno
# Processing Record 32 of Set 15 | kasempa
# Processing Record 33 of Set 15 | caravelas
# Processing Record 34 of Set 15 | talara
# Processing Record 35 of Set 15 | waipawa
# Processing Record 36 of Set 15 | mananjary
# Processing Record 37 of Set 15 | vila velha
# Processing Record 38 of Set 15 | duluth
# Processing Record 39 of Set 15 | ostersund
# Processing Record 40 of Set 15 | kichera
# Processing Record 41 of Set 15 | charagua
# Processing Record 42 of Set 15 | sogdiondon
# City not found. Skipping...
# Processing Record 43 of Set 15 | westport
# Processing Record 44 of Set 15 | fasa
# Processing Record 45 of Set 15 | rani
# Processing Record 46 of Set 15 | axim
# Processing Record 47 of Set 15 | saint-georges
# Processing Record 48 of Set 15 | izhma
# Processing Record 49 of Set 15 | zhezkazgan
# Processing Record 50 of Set 15 | brigantine
# Processing Record 1 of Set 16 | abnub
# Processing Record 2 of Set 16 | umm kaddadah
# Processing Record 3 of Set 16 | mitu
# Processing Record 4 of Set 16 | fort saint john
# City not found. Skipping...
# Processing Record 5 of Set 16 | salou
# Processing Record 6 of Set 16 | port-cartier
# Processing Record 7 of Set 16 | yokadouma
# Processing Record 8 of Set 16 | mayumba
# Processing Record 9 of Set 16 | ixtapa
# Processing Record 10 of Set 16 | bridgewater
# Processing Record 11 of Set 16 | livingston
# Processing Record 12 of Set 16 | chapadinha
# Processing Record 13 of Set 16 | shirokiy
# Processing Record 14 of Set 16 | aksu
# Processing Record 15 of Set 16 | aasiaat
# Processing Record 16 of Set 16 | malmesbury
# Processing Record 17 of Set 16 | terrace bay
# Processing Record 18 of Set 16 | tortoli
# Processing Record 19 of Set 16 | grand-santi
# Processing Record 20 of Set 16 | natal
# Processing Record 21 of Set 16 | tabou
# Processing Record 22 of Set 16 | muzhi
# Processing Record 23 of Set 16 | kushima
# Processing Record 24 of Set 16 | grants
# Processing Record 25 of Set 16 | leshukonskoye
# Processing Record 26 of Set 16 | launceston
# Processing Record 27 of Set 16 | petatlan
# Processing Record 28 of Set 16 | rio brilhante
# Processing Record 29 of Set 16 | mus
# Processing Record 30 of Set 16 | tenenkou
# Processing Record 31 of Set 16 | phetchaburi
# Processing Record 32 of Set 16 | oytal
# Processing Record 33 of Set 16 | vacaria
# Processing Record 34 of Set 16 | omsukchan
# Processing Record 35 of Set 16 | samarai
# Processing Record 36 of Set 16 | pedernales
# Processing Record 37 of Set 16 | mumbwa
# Processing Record 38 of Set 16 | kalmunai
# Processing Record 39 of Set 16 | kalemie
# Processing Record 40 of Set 16 | shieli
# Processing Record 41 of Set 16 | devyatka
# City not found. Skipping...
# Processing Record 42 of Set 16 | yinchuan
# Processing Record 43 of Set 16 | shimoda
# Processing Record 44 of Set 16 | healdsburg
# Processing Record 45 of Set 16 | ha giang
# Processing Record 46 of Set 16 | kunming
# Processing Record 47 of Set 16 | elban
# Processing Record 48 of Set 16 | balurghat
# Processing Record 49 of Set 16 | ust-maya
# Processing Record 50 of Set 16 | balkanabat
# Processing Record 1 of Set 17 | meiganga
# Processing Record 2 of Set 17 | stonewall
# Processing Record 3 of Set 17 | hojai
# Processing Record 4 of Set 17 | inta
# Processing Record 5 of Set 17 | bardiyah
# Processing Record 6 of Set 17 | udachnyy
# Processing Record 7 of Set 17 | prado
# Processing Record 8 of Set 17 | sergeyevka
# Processing Record 9 of Set 17 | vila do maio
# Processing Record 10 of Set 17 | middelburg
# Processing Record 11 of Set 17 | tashla
# Processing Record 12 of Set 17 | bejucal
# Processing Record 13 of Set 17 | esqueda
# Processing Record 14 of Set 17 | fria
# Processing Record 15 of Set 17 | gueret
# Processing Record 16 of Set 17 | bend
# Processing Record 17 of Set 17 | pocone
# Processing Record 18 of Set 17 | olafsvik
# Processing Record 19 of Set 17 | ola
# Processing Record 20 of Set 17 | baybay
# Processing Record 21 of Set 17 | isilkul
# Processing Record 22 of Set 17 | altea
# Processing Record 23 of Set 17 | derzhavinsk
# Processing Record 24 of Set 17 | aklavik
# Processing Record 25 of Set 17 | labrea
# Processing Record 26 of Set 17 | atlantic city
# Processing Record 27 of Set 17 | imeni babushkina
# Processing Record 28 of Set 17 | ikongo
# Processing Record 29 of Set 17 | shama
# Processing Record 30 of Set 17 | linfen
# Processing Record 31 of Set 17 | sayyan
# Processing Record 32 of Set 17 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 17 | dicabisagan
# Processing Record 34 of Set 17 | suntar
# Processing Record 35 of Set 17 | macas
# Processing Record 36 of Set 17 | faya
# Processing Record 37 of Set 17 | haldwani
# Processing Record 38 of Set 17 | miles city
# Processing Record 39 of Set 17 | berbera
# Processing Record 40 of Set 17 | jamame
# Processing Record 41 of Set 17 | quelimane
# Processing Record 42 of Set 17 | bac lieu
# Processing Record 43 of Set 17 | ossora
# Processing Record 44 of Set 17 | new cumnock
# Processing Record 45 of Set 17 | shibetsu
# Processing Record 46 of Set 17 | kandi
# Processing Record 47 of Set 17 | serov
# Processing Record 48 of Set 17 | khandyga
# Processing Record 49 of Set 17 | olyka
# Processing Record 50 of Set 17 | goderich
# Processing Record 1 of Set 18 | phan thiet
# Processing Record 2 of Set 18 | clarksdale
# Processing Record 3 of Set 18 | ambon
# Processing Record 4 of Set 18 | vestmannaeyjar
# Processing Record 5 of Set 18 | basoko
# Processing Record 6 of Set 18 | gaoual
# Processing Record 7 of Set 18 | bhaderwah
# Processing Record 8 of Set 18 | severnyy
# Processing Record 9 of Set 18 | kyshtovka
# Processing Record 10 of Set 18 | ruteng
# Processing Record 11 of Set 18 | yenagoa
# Processing Record 12 of Set 18 | tsienyane
# City not found. Skipping...
# Processing Record 13 of Set 18 | victor harbor
# Processing Record 14 of Set 18 | waddan
# Processing Record 15 of Set 18 | diamantino
# Processing Record 16 of Set 18 | bobo dioulasso
# Processing Record 17 of Set 18 | wajima
# Processing Record 18 of Set 18 | mapiri
# Processing Record 19 of Set 18 | garowe
# Processing Record 20 of Set 18 | bayanday
# Processing Record 21 of Set 18 | sibolga
# Processing Record 22 of Set 18 | sola
# Processing Record 23 of Set 18 | cap-aux-meules
# Processing Record 24 of Set 18 | lasa
# Processing Record 25 of Set 18 | obihiro
# Processing Record 26 of Set 18 | zelenoborskiy
# Processing Record 27 of Set 18 | romans-sur-isere
# Processing Record 28 of Set 18 | pampierstad
# Processing Record 29 of Set 18 | harper
# Processing Record 30 of Set 18 | camacha
# Processing Record 31 of Set 18 | san quintin
# Processing Record 32 of Set 18 | roald
# Processing Record 33 of Set 18 | yorkton
# Processing Record 34 of Set 18 | anloga
# Processing Record 35 of Set 18 | gotsu
# Processing Record 36 of Set 18 | killarney
# Processing Record 37 of Set 18 | sisophon
# Processing Record 38 of Set 18 | dayong
# Processing Record 39 of Set 18 | juegang
# Processing Record 40 of Set 18 | buraydah
# Processing Record 41 of Set 18 | forio
# Processing Record 42 of Set 18 | tazovskiy
# Processing Record 43 of Set 18 | griffith
# Processing Record 44 of Set 18 | chupa
# Processing Record 45 of Set 18 | bunia
# Processing Record 46 of Set 18 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 18 | verkh-usugli
# Processing Record 48 of Set 18 | karlskoga
# Processing Record 49 of Set 18 | dmitriyevka
# Processing Record 50 of Set 18 | itarema
# Processing Record 1 of Set 19 | satkhira
# Processing Record 2 of Set 19 | kourou
# Processing Record 3 of Set 19 | stornoway
# Processing Record 4 of Set 19 | matagami
# Processing Record 5 of Set 19 | korla
# Processing Record 6 of Set 19 | dzhebariki-khaya
# Processing Record 7 of Set 19 | rovaniemi
# Processing Record 8 of Set 19 | gannan
# Processing Record 9 of Set 19 | kangaatsiaq
# Processing Record 10 of Set 19 | barao de melgaco
# Processing Record 11 of Set 19 | one hundred mile house
# City not found. Skipping...
# Processing Record 12 of Set 19 | valley city
# Processing Record 13 of Set 19 | ogden
# Processing Record 14 of Set 19 | lyubeshiv
# City not found. Skipping...
# Processing Record 15 of Set 19 | brinkovskaya
# Processing Record 16 of Set 19 | kamra
# Processing Record 17 of Set 19 | kadoshkino
# Processing Record 18 of Set 19 | empalme
# Processing Record 19 of Set 19 | ndele
# Processing Record 20 of Set 19 | aktau
# Processing Record 21 of Set 19 | corowa
# Processing Record 22 of Set 19 | karratha
# Processing Record 23 of Set 19 | tambovka
# Processing Record 24 of Set 19 | lusambo
# Processing Record 25 of Set 19 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 19 | atar
# Processing Record 27 of Set 19 | the valley
# Processing Record 28 of Set 19 | kaabong
# Processing Record 29 of Set 19 | onda
# Processing Record 30 of Set 19 | wittmund
# Processing Record 31 of Set 19 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 19 | cuiaba
# Processing Record 33 of Set 19 | puerto carreno
# Processing Record 34 of Set 19 | soligalich
# Processing Record 35 of Set 19 | jardim
# Processing Record 36 of Set 19 | soyalo
# Processing Record 37 of Set 19 | uribia
# Processing Record 38 of Set 19 | camargo
# Processing Record 39 of Set 19 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 40 of Set 19 | tobermory
# Processing Record 41 of Set 19 | sakakah
# Processing Record 42 of Set 19 | motygino
# Processing Record 43 of Set 19 | camajuani
# Processing Record 44 of Set 19 | dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 19 | aldan
# Processing Record 46 of Set 19 | kloulklubed
# Processing Record 47 of Set 19 | sobradinho
# Processing Record 48 of Set 19 | caruray
# Processing Record 49 of Set 19 | tabulbah
# City not found. Skipping...
# Processing Record 50 of Set 19 | bara
# Processing Record 1 of Set 20 | bagdarin
# Processing Record 2 of Set 20 | haimen
# Processing Record 3 of Set 20 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 20 | yekaterinoslavka
# Processing Record 5 of Set 20 | jaicos
# Processing Record 6 of Set 20 | qandahar
# City not found. Skipping...
# Processing Record 7 of Set 20 | jalu
# Processing Record 8 of Set 20 | eruwa
# Processing Record 9 of Set 20 | iralaya
# Processing Record 10 of Set 20 | ksenyevka
# City not found. Skipping...
# Processing Record 11 of Set 20 | vagur
# Processing Record 12 of Set 20 | antofagasta
# Processing Record 13 of Set 20 | salalah
# Processing Record 14 of Set 20 | choix
# Processing Record 15 of Set 20 | itimadpur
# Processing Record 16 of Set 20 | kadyy
# Processing Record 17 of Set 20 | puttur
# Processing Record 18 of Set 20 | can
# Processing Record 19 of Set 20 | esna
# Processing Record 20 of Set 20 | muisne
# Processing Record 21 of Set 20 | haines junction
# Processing Record 22 of Set 20 | wuning
# Processing Record 23 of Set 20 | wenling
# Processing Record 24 of Set 20 | olovyannaya
# Processing Record 25 of Set 20 | san isidro
# Processing Record 26 of Set 20 | ibra
# Processing Record 27 of Set 20 | morro bay
# Processing Record 28 of Set 20 | yerbogachen
# Processing Record 29 of Set 20 | chukhloma
# Processing Record 30 of Set 20 | dillon
# Processing Record 31 of Set 20 | entebbe
# Processing Record 32 of Set 20 | kashi
# Processing Record 33 of Set 20 | angleton
# Processing Record 34 of Set 20 | necochea
# Processing Record 35 of Set 20 | santa cruz
# Processing Record 36 of Set 20 | monywa
# Processing Record 37 of Set 20 | simao
# Processing Record 38 of Set 20 | sao jose do calcado
# Processing Record 39 of Set 20 | guasdualito
# Processing Record 40 of Set 20 | samandag
# Processing Record 41 of Set 20 | pangai
# Processing Record 42 of Set 20 | san carlos
# Processing Record 43 of Set 20 | nikolayevsk-na-amure
# Processing Record 44 of Set 20 | ulyanovka
# Processing Record 45 of Set 20 | marseille
# Processing Record 46 of Set 20 | miquelon
# Processing Record 47 of Set 20 | teyateyaneng
# Processing Record 48 of Set 20 | pontianak
# Processing Record 49 of Set 20 | awbari
# Processing Record 50 of Set 20 | mezen
# Processing Record 1 of Set 21 | terrace
# Processing Record 2 of Set 21 | smidovich
# Processing Record 3 of Set 21 | qasigiannguit
# Processing Record 4 of Set 21 | khudumelapye
# Processing Record 5 of Set 21 | conakry
# Processing Record 6 of Set 21 | xifeng
# Processing Record 7 of Set 21 | pisco
# Processing Record 8 of Set 21 | ayan
# Processing Record 9 of Set 21 | hami
# Processing Record 10 of Set 21 | esil
# Processing Record 11 of Set 21 | gold coast
# Processing Record 12 of Set 21 | kamaishi
# Processing Record 13 of Set 21 | mvomero
# Processing Record 14 of Set 21 | hof
# Processing Record 15 of Set 21 | san-pedro
# Processing Record 16 of Set 21 | ascension
# Processing Record 17 of Set 21 | hay river
# Processing Record 18 of Set 21 | wynyard
# Processing Record 19 of Set 21 | ihosy
# Processing Record 20 of Set 21 | gedo
# Processing Record 21 of Set 21 | sitio novo do tocantins
# Processing Record 22 of Set 21 | umm lajj
# Processing Record 23 of Set 21 | lujan
# Processing Record 24 of Set 21 | muravlenko
# Processing Record 25 of Set 21 | arona
# Processing Record 26 of Set 21 | pascagoula
# Processing Record 27 of Set 21 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 21 | santa maria
# Processing Record 29 of Set 21 | olinda
# Processing Record 30 of Set 21 | kalabo
# Processing Record 31 of Set 21 | nalvo
# Processing Record 32 of Set 21 | kununurra
# Processing Record 33 of Set 21 | banjar
# Processing Record 34 of Set 21 | young
# Processing Record 35 of Set 21 | blackwater
# Processing Record 36 of Set 21 | finnsnes
# Processing Record 37 of Set 21 | harrison
# Processing Record 38 of Set 21 | gizo
# Processing Record 39 of Set 21 | nipawin
# Processing Record 40 of Set 21 | tubuala
# Processing Record 41 of Set 21 | porto franco
# Processing Record 42 of Set 21 | tadine
# Processing Record 43 of Set 21 | kulhudhuffushi
# Processing Record 44 of Set 21 | warri
# Processing Record 45 of Set 21 | pishin
# Processing Record 46 of Set 21 | sedelnikovo
# City not found. Skipping...
# Processing Record 47 of Set 21 | virginia beach
# Processing Record 48 of Set 21 | linchuan
# City not found. Skipping...
# Processing Record 49 of Set 21 | temirtau
# Processing Record 50 of Set 21 | mlonggo
# Processing Record 1 of Set 22 | banepa
# Processing Record 2 of Set 22 | irtyshskiy
# Processing Record 3 of Set 22 | klyuchi
# Processing Record 4 of Set 22 | parnamirim
# Processing Record 5 of Set 22 | orapa
# Processing Record 6 of Set 22 | bolshiye berezniki
# City not found. Skipping...
# Processing Record 7 of Set 22 | nacozari
# Processing Record 8 of Set 22 | baruun-urt
# Processing Record 9 of Set 22 | baiyin
# Processing Record 10 of Set 22 | porosozero
# Processing Record 11 of Set 22 | la rioja
# Processing Record 12 of Set 22 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 22 | marquette
# Processing Record 14 of Set 22 | kapit
# Processing Record 15 of Set 22 | maryborough
# Processing Record 16 of Set 22 | azad shahr
# Processing Record 17 of Set 22 | kaura namoda
# Processing Record 18 of Set 22 | paita
# Processing Record 19 of Set 22 | bartica
# Processing Record 20 of Set 22 | sulangan
# Processing Record 21 of Set 22 | nizhniy odes
# Processing Record 22 of Set 22 | kirakira
# Processing Record 23 of Set 22 | high level
# Processing Record 24 of Set 22 | birin
# Processing Record 25 of Set 22 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 22 | basco
# Processing Record 27 of Set 22 | schwaz
# Processing Record 28 of Set 22 | novobureyskiy
# Processing Record 29 of Set 22 | madimba
# Processing Record 30 of Set 22 | shatrovo
# Processing Record 31 of Set 22 | bayir
# Processing Record 32 of Set 22 | beyneu
# Processing Record 33 of Set 22 | mujiayingzi
# Processing Record 34 of Set 22 | san marcos
# Processing Record 35 of Set 22 | tosya
# Processing Record 36 of Set 22 | nelson bay
# Processing Record 37 of Set 22 | carbonia
# Processing Record 38 of Set 22 | defiance
# Processing Record 39 of Set 22 | panindicuaro
# Processing Record 40 of Set 22 | dina
# Processing Record 41 of Set 22 | ngunguru
# Processing Record 42 of Set 22 | penticton
# Processing Record 43 of Set 22 | khanpur
# Processing Record 44 of Set 22 | lufilufi
# Processing Record 45 of Set 22 | igarka
# ...
# Processing Record 39 of Set 49 | westerly
# Processing Record 40 of Set 49 | el dorado
# Processing Record 41 of Set 49 | hong gai
# Processing Record 42 of Set 49 | passo de camaragibe
# Processing Record 43 of Set 49 | maine-soroa
# Processing Record 44 of Set 49 | renqiu
# Processing Record 45 of Set 49 | camopi
# Processing Record 46 of Set 49 | caucaia
# Processing Record 47 of Set 49 | khakhea
# Processing Record 48 of Set 49 | jibuti
# Processing Record 49 of Set 49 | guarapari
# Processing Record 50 of Set 49 | nova russas
# Processing Record 1 of Set 50 | umiray
# Processing Record 2 of Set 50 | lloret de mar
# Processing Record 3 of Set 50 | murgab
# Processing Record 4 of Set 50 | sohag
# Processing Record 5 of Set 50 | calbuco
# Processing Record 6 of Set 50 | javornik
# Processing Record 7 of Set 50 | popondetta
# Processing Record 8 of Set 50 | koboldo
# City not found. Skipping...
# Processing Record 9 of Set 50 | manado
# Processing Record 10 of Set 50 | bereznik
# Processing Record 11 of Set 50 | oriximina
# Processing Record 12 of Set 50 | baryatino
# Processing Record 13 of Set 50 | toora-khem
# Processing Record 14 of Set 50 | kirksville
# Processing Record 15 of Set 50 | bamboo
# Processing Record 16 of Set 50 | yeppoon
# Processing Record 17 of Set 50 | seabra
# Processing Record 18 of Set 50 | dombas
# Processing Record 19 of Set 50 | rock springs
# Processing Record 20 of Set 50 | istmina
# Processing Record 21 of Set 50 | mpanda
# Processing Record 22 of Set 50 | svirstroy
# Processing Record 23 of Set 50 | general bravo
# Processing Record 24 of Set 50 | huarmey
# Processing Record 25 of Set 50 | ulaanbaatar
# Processing Record 26 of Set 50 | tochigi
# Processing Record 27 of Set 50 | semey
# Processing Record 28 of Set 50 | belgrade
# Processing Record 29 of Set 50 | orchard homes
# Processing Record 30 of Set 50 | lahaina
# Processing Record 31 of Set 50 | richmond
# Processing Record 32 of Set 50 | eminabad
# Processing Record 33 of Set 50 | tripoli
# Processing Record 34 of Set 50 | goma
# Processing Record 35 of Set 50 | todos santos
# Processing Record 36 of Set 50 | madang
# Processing Record 37 of Set 50 | libenge
# Processing Record 38 of Set 50 | gushikawa
# Processing Record 39 of Set 50 | krabi
# Processing Record 40 of Set 50 | tahta
# Processing Record 41 of Set 50 | khorramshahr
# Processing Record 42 of Set 50 | bodrum
# Processing Record 43 of Set 50 | cookeville
# Processing Record 44 of Set 50 | sampit
# Processing Record 45 of Set 50 | jefferson city
# Processing Record 46 of Set 50 | garbolovo
# Processing Record 47 of Set 50 | thunder bay
# Processing Record 48 of Set 50 | dzilam gonzalez
# Processing Record 49 of Set 50 | yugorsk
# Processing Record 50 of Set 50 | krasnousolskiy
# City not found. Skipping...
# Processing Record 1 of Set 51 | minsk
# Processing Record 2 of Set 51 | bijar
# Processing Record 3 of Set 51 | sao felix do xingu
# Processing Record 4 of Set 51 | coxim
# Processing Record 5 of Set 51 | sidrolandia
# Processing Record 6 of Set 51 | prince george
# Processing Record 7 of Set 51 | ivanovka
# Processing Record 8 of Set 51 | konakovo
# Processing Record 9 of Set 51 | sinjah
# City not found. Skipping...
# Processing Record 10 of Set 51 | vredendal
# Processing Record 11 of Set 51 | salinas
# Processing Record 12 of Set 51 | kon tum
# Processing Record 13 of Set 51 | iracoubo
# Processing Record 14 of Set 51 | zouxian
# City not found. Skipping...
# Processing Record 15 of Set 51 | mchinji
# Processing Record 16 of Set 51 | norrkoping
# Processing Record 17 of Set 51 | zolotyy potik
# Processing Record 18 of Set 51 | ullapool
# Processing Record 19 of Set 51 | brasileia
# Processing Record 20 of Set 51 | reus
# Processing Record 21 of Set 51 | villablino
# Processing Record 22 of Set 51 | lampa
# Processing Record 23 of Set 51 | imatra
# Processing Record 24 of Set 51 | skogn
# Processing Record 25 of Set 51 | candido mendes
# Processing Record 26 of Set 51 | bogen
# Processing Record 27 of Set 51 | wismar
# Processing Record 28 of Set 51 | sarh
# Processing Record 29 of Set 51 | methoni
# Processing Record 30 of Set 51 | shikhany
# Processing Record 31 of Set 51 | general pico
# Processing Record 32 of Set 51 | brunsbuttel
# Processing Record 33 of Set 51 | megion
# Processing Record 34 of Set 51 | el rosal
# Processing Record 35 of Set 51 | dumas
# Processing Record 36 of Set 51 | huitziltepec
# Processing Record 37 of Set 51 | kielce
# Processing Record 38 of Set 51 | mopti
# Processing Record 39 of Set 51 | angoche
# Processing Record 40 of Set 51 | rantauprapat
# Processing Record 41 of Set 51 | zolotinka
# City not found. Skipping...
# Processing Record 42 of Set 51 | campos altos
# Processing Record 43 of Set 51 | kaseda
# Processing Record 44 of Set 51 | jaguaruna
# Processing Record 45 of Set 51 | bluefield
# Processing Record 46 of Set 51 | oshnaviyeh
# Processing Record 47 of Set 51 | cicevac
# Processing Record 48 of Set 51 | sol-iletsk
# Processing Record 49 of Set 51 | pokrovka
# Processing Record 50 of Set 51 | elmira
# Processing Record 1 of Set 52 | tallahassee
# Processing Record 2 of Set 52 | los lunas
# Processing Record 3 of Set 52 | wamba
# Processing Record 4 of Set 52 | kegayli
# City not found. Skipping...
# Processing Record 5 of Set 52 | ahumada
# City not found. Skipping...
# Processing Record 6 of Set 52 | clarksburg
# Processing Record 7 of Set 52 | olkhovka
# Processing Record 8 of Set 52 | panique
# Processing Record 9 of Set 52 | salgar
# Processing Record 10 of Set 52 | barabai
# Processing Record 11 of Set 52 | rorvik
# Processing Record 12 of Set 52 | renfrew
# Processing Record 13 of Set 52 | penaflor
# Processing Record 14 of Set 52 | taos
# Processing Record 15 of Set 52 | masty
# Processing Record 16 of Set 52 | sonepur
# Processing Record 17 of Set 52 | mazyr
# Processing Record 18 of Set 52 | yakeshi
# Processing Record 19 of Set 52 | plateros
# Processing Record 20 of Set 52 | bingol
# Processing Record 21 of Set 52 | vigeland
# Processing Record 22 of Set 52 | gawler
# Processing Record 23 of Set 52 | pelotas
# Processing Record 24 of Set 52 | kaitong
# Processing Record 25 of Set 52 | krasnovishersk
# Processing Record 26 of Set 52 | balabac
# Processing Record 27 of Set 52 | puerto madero
# Processing Record 28 of Set 52 | tema
# Processing Record 29 of Set 52 | alberdi
# Processing Record 30 of Set 52 | orodara
# Processing Record 31 of Set 52 | ajdabiya
# Processing Record 32 of Set 52 | ust-nera
# Processing Record 33 of Set 52 | carmen
# Processing Record 34 of Set 52 | grenada
# Processing Record 35 of Set 52 | lillooet
# Processing Record 36 of Set 52 | uvalde
# Processing Record 37 of Set 52 | bachaquero
# Processing Record 38 of Set 52 | manaus
# Processing Record 39 of Set 52 | suratgarh
# Processing Record 40 of Set 52 | libreville
# Processing Record 41 of Set 52 | chauny
# Processing Record 42 of Set 52 | hanmer springs
# Processing Record 43 of Set 52 | two rivers
# Processing Record 44 of Set 52 | dauriya
# Processing Record 45 of Set 52 | nanma
# Processing Record 46 of Set 52 | fredericksburg
# Processing Record 47 of Set 52 | velsk
# Processing Record 48 of Set 52 | irece
# Processing Record 49 of Set 52 | hudiksvall
# Processing Record 50 of Set 52 | qidong
# Processing Record 1 of Set 53 | cao bang
# Processing Record 2 of Set 53 | boyolangu
# Processing Record 3 of Set 53 | tromso
# Processing Record 4 of Set 53 | shymkent
# Processing Record 5 of Set 53 | zepce
# Processing Record 6 of Set 53 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 53 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 53 | medea
# Processing Record 9 of Set 53 | kainantu
# Processing Record 10 of Set 53 | pundaguitan
# Processing Record 11 of Set 53 | kabo
# Processing Record 12 of Set 53 | lebyazhye
# Processing Record 13 of Set 53 | slobidka
# Processing Record 14 of Set 53 | marondera
# Processing Record 15 of Set 53 | marovoay
# Processing Record 16 of Set 53 | whitefish
# Processing Record 17 of Set 53 | turtas
# Processing Record 18 of Set 53 | glubokoe
# City not found. Skipping...
# Processing Record 19 of Set 53 | verkhnyaya pyshma
# Processing Record 20 of Set 53 | christchurch
# Processing Record 21 of Set 53 | murud
# Processing Record 22 of Set 53 | chipinge
# Processing Record 23 of Set 53 | fershampenuaz
# Processing Record 24 of Set 53 | shenjiamen
# Processing Record 25 of Set 53 | raga
# Processing Record 26 of Set 53 | basyanovskiy
# City not found. Skipping...
# Processing Record 27 of Set 53 | ayolas
# Processing Record 28 of Set 53 | cave spring
# Processing Record 29 of Set 53 | linguere
# Processing Record 30 of Set 53 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 53 | katsiveli
# City not found. Skipping...
# Processing Record 32 of Set 53 | makokou
# Processing Record 33 of Set 53 | abu zabad
# Processing Record 34 of Set 53 | debre zeyit
# Processing Record 35 of Set 53 | morozovsk
# Processing Record 36 of Set 53 | novooleksiyivka
# Processing Record 37 of Set 53 | masuguru
# Processing Record 38 of Set 53 | okato
# Processing Record 39 of Set 53 | fairlie
# Processing Record 40 of Set 53 | thanh hoa
# Processing Record 41 of Set 53 | ledziny
# Processing Record 42 of Set 53 | hatillo
# Processing Record 43 of Set 53 | zaysan
# Processing Record 44 of Set 53 | homewood
# Processing Record 45 of Set 53 | macaboboni
# City not found. Skipping...
# Processing Record 46 of Set 53 | yaan
# Processing Record 47 of Set 53 | tau
# Processing Record 48 of Set 53 | pitkyaranta
# Processing Record 49 of Set 53 | komatipoort
# Processing Record 50 of Set 53 | bela vista de goias
# Processing Record 1 of Set 54 | saco
# Processing Record 2 of Set 54 | cumaribo
# City not found. Skipping...
# Processing Record 3 of Set 54 | conde
# Processing Record 4 of Set 54 | marfino
# Processing Record 5 of Set 54 | jatiroto
# Processing Record 6 of Set 54 | polunochnoye
# Processing Record 7 of Set 54 | barentu
# Processing Record 8 of Set 54 | navirai
# Processing Record 9 of Set 54 | desaguadero
# Processing Record 10 of Set 54 | srandakan
# Processing Record 11 of Set 54 | abu kamal
# Processing Record 12 of Set 54 | yurimaguas
# Processing Record 13 of Set 54 | san antonio
# Processing Record 14 of Set 54 | riohacha
# Processing Record 15 of Set 54 | oxelosund
# Processing Record 16 of Set 54 | hombrechtikon
# Processing Record 17 of Set 54 | malumfashi
# Processing Record 18 of Set 54 | sembe
# Processing Record 19 of Set 54 | gigmoto
# Processing Record 20 of Set 54 | nenjiang
# Processing Record 21 of Set 54 | pelym
# Processing Record 22 of Set 54 | guaruja
# Processing Record 23 of Set 54 | cancun
# Processing Record 24 of Set 54 | tambul
# City not found. Skipping...
# Processing Record 25 of Set 54 | zhicheng
# Processing Record 26 of Set 54 | castellammare di stabia
# Processing Record 27 of Set 54 | new braunfels
# Processing Record 28 of Set 54 | alcobendas
# Processing Record 29 of Set 54 | seddon
# Processing Record 30 of Set 54 | hellin
# Processing Record 31 of Set 54 | buritis
# Processing Record 32 of Set 54 | gazni
# City not found. Skipping...
# Processing Record 33 of Set 54 | lamu
# Processing Record 34 of Set 54 | acajutla
# Processing Record 35 of Set 54 | wladyslawowo
# Processing Record 36 of Set 54 | ussel
# Processing Record 37 of Set 54 | shuangcheng
# Processing Record 38 of Set 54 | ongandjera
# Processing Record 39 of Set 54 | pointe michel
# Processing Record 40 of Set 54 | monte santo
# Processing Record 41 of Set 54 | sidi ali
# Processing Record 42 of Set 54 | igrim
# Processing Record 43 of Set 54 | heerenveen
# Processing Record 44 of Set 54 | portree
# Processing Record 45 of Set 54 | emilio carranza
# Processing Record 46 of Set 54 | redding
# Processing Record 47 of Set 54 | santa maria del oro
# Processing Record 48 of Set 54 | loubomo
# Processing Record 49 of Set 54 | dongsheng
# Processing Record 50 of Set 54 | rockhampton
# Processing Record 1 of Set 55 | ranau
# Processing Record 2 of Set 55 | el faiyum
# City not found. Skipping...
# Processing Record 3 of Set 55 | johi
# Processing Record 4 of Set 55 | puerto rico
# Processing Record 5 of Set 55 | guiratinga
# Processing Record 6 of Set 55 | vaitape
# Processing Record 7 of Set 55 | astoria
# Processing Record 8 of Set 55 | sandnessjoen
# Processing Record 9 of Set 55 | burgersdorp
# Processing Record 10 of Set 55 | les cayes
# Processing Record 11 of Set 55 | bainbridge
# Processing Record 12 of Set 55 | xudat
# Processing Record 13 of Set 55 | karabash
# Processing Record 14 of Set 55 | kasama
# Processing Record 15 of Set 55 | tocopilla
# Processing Record 16 of Set 55 | tabora
# Processing Record 17 of Set 55 | fuerte olimpo
# Processing Record 18 of Set 55 | dzheyrakh
# Processing Record 19 of Set 55 | chara
# Processing Record 20 of Set 55 | uitenhage
# Processing Record 21 of Set 55 | grootfontein
# Processing Record 22 of Set 55 | verkhnyaya inta
# Processing Record 23 of Set 55 | alexandria
# Processing Record 24 of Set 55 | areia branca
# Processing Record 25 of Set 55 | owando
# Processing Record 26 of Set 55 | borger
# Processing Record 27 of Set 55 | san ramon
# Processing Record 28 of Set 55 | kazerun
# Processing Record 29 of Set 55 | alta gracia
# Processing Record 30 of Set 55 | inverness
# Processing Record 31 of Set 55 | hooglede
# Processing Record 32 of Set 55 | namtsy
# Processing Record 33 of Set 55 | buta
# Processing Record 34 of Set 55 | leiva
# Processing Record 35 of Set 55 | levelland
# Processing Record 36 of Set 55 | khalandritsa
# City not found. Skipping...
# Processing Record 37 of Set 55 | mocoa
# Processing Record 38 of Set 55 | cefalu
# Processing Record 39 of Set 55 | beitbridge
# Processing Record 40 of Set 55 | bojaya
# City not found. Skipping...
# Processing Record 41 of Set 55 | rincon
# Processing Record 42 of Set 55 | solsvik
# City not found. Skipping...
# Processing Record 43 of Set 55 | suba
# Processing Record 44 of Set 55 | karpogory
# Processing Record 45 of Set 55 | rongcheng
# Processing Record 46 of Set 55 | pavlovo
# Processing Record 47 of Set 55 | povolzhskiy
# Processing Record 48 of Set 55 | dibaya
# City not found. Skipping...
# Processing Record 49 of Set 55 | geresk
# City not found. Skipping...
# Processing Record 50 of Set 55 | la grande
# Processing Record 1 of Set 56 | tacoronte
# Processing Record 2 of Set 56 | limbang
# Processing Record 3 of Set 56 | benjamin constant
# Processing Record 4 of Set 56 | yelniki
# Processing Record 5 of Set 56 | zavetnoye
# Processing Record 6 of Set 56 | vaasa
# Processing Record 7 of Set 56 | utrecht
# Processing Record 8 of Set 56 | nadvoitsy
# Processing Record 9 of Set 56 | paredon
# Processing Record 10 of Set 56 | marathopolis
# City not found. Skipping...
# Processing Record 11 of Set 56 | finschhafen
# Processing Record 12 of Set 56 | catia la mar
# Processing Record 13 of Set 56 | olavarria
# Processing Record 14 of Set 56 | hanna
# Processing Record 15 of Set 56 | tornio
# Processing Record 16 of Set 56 | gashua
# Processing Record 17 of Set 56 | mergui
# City not found. Skipping...
# Processing Record 18 of Set 56 | isiro
# Processing Record 19 of Set 56 | lesosibirsk
# Processing Record 20 of Set 56 | kuito
# Processing Record 21 of Set 56 | aleppo
# Processing Record 22 of Set 56 | brownwood
# Processing Record 23 of Set 56 | jinchengjiang
# City not found. Skipping...
# Processing Record 24 of Set 56 | shenzhen
# Processing Record 25 of Set 56 | tabukiniberu
# City not found. Skipping...
# Processing Record 26 of Set 56 | golkoy
# Processing Record 27 of Set 56 | shamary
# Processing Record 28 of Set 56 | puerto suarez
# Processing Record 29 of Set 56 | chama
# Processing Record 30 of Set 56 | panaba
# Processing Record 31 of Set 56 | pakala
# Processing Record 32 of Set 56 | talcahuano
# Processing Record 33 of Set 56 | hammel
# Processing Record 34 of Set 56 | eydhafushi
# Processing Record 35 of Set 56 | ojinaga
# Processing Record 36 of Set 56 | lushunkou
# City not found. Skipping...
# Processing Record 37 of Set 56 | hurghada
# Processing Record 38 of Set 56 | tanshui
# City not found. Skipping...
# Processing Record 39 of Set 56 | sehithwa
# Processing Record 40 of Set 56 | mansa
# Processing Record 41 of Set 56 | arth
# Processing Record 42 of Set 56 | orsha
# Processing Record 43 of Set 56 | sissach
# Processing Record 44 of Set 56 | karistos
# City not found. Skipping...
# Processing Record 45 of Set 56 | uray
# Processing Record 46 of Set 56 | luziania
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Tally the number of cities
len(city_data)
# Out:
# 2566

# %% [markdown]
# #### Step 05
# Add the data to a DF

# %%
#Convert the array of dictionaries to a pandas DF
city_data_df = pd.DataFrame(city_data)
city_data_df.index.name = 'City_ID'
city_data_df.str.title('Current Description')

#Check the DF
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Feels Like  Min Temp  Max Temp  \
# City_ID
# 0               Lagoa  39.0500  -27.9833       62.53     63.00     63.00
# 1              Yarada  17.6500   83.2667       78.66     77.32     77.32
# 2          Marienburg  54.0359   19.0266       23.86     29.89     33.46
# 3            Havelock  34.8791  -76.9013       54.00     50.05     57.15
# 4         Provideniya  64.3833 -173.3000       15.48     26.37     26.71
# 5            Tasiilaq  65.6145  -37.6368       17.31     29.66     29.66
# 6           Carnarvon -24.8667  113.6333       83.32     80.67     80.67
# 7             Rikitea -23.1203 -134.9692       77.67     76.89     76.89
# 8            Behbahan  30.5959   50.2417       45.48     48.16     51.12
# 9        Norman Wells  65.2820 -126.8329      -25.96    -13.36    -13.36
#
#          Humidity  Cloudiness  Wind Speed Country Current Description  \
# City_ID
# 0              75          66       11.48      PT       broken clouds
# 1              83          75        5.75      IN                mist
# 2              88         100       10.38      PL     overcast clouds
# 3              89          50        1.25      US    scattered clouds
# 4              86          75       13.42      RU                snow
# 5              90         100       18.70      GL          light snow
# 6              65           0       17.27      AU           clear sky
# 7              72         100        6.22      PF     overcast clouds
# 8              32          74        5.99      IR       broken clouds
# 9              81          37        5.57      CA    scattered clouds
#
#                         Date
# City_ID
# 0        2021-12-06 02:25:35
# 1        2021-12-06 02:25:36
# 2        2021-12-06 02:25:36
# 3        2021-12-06 02:25:36
# 4        2021-12-06 02:25:37
# 5        2021-12-06 02:25:37
# 6        2021-12-06 02:25:37
# 7        2021-12-06 02:25:38
# 8        2021-12-06 02:25:38
# 9        2021-12-06 02:25:38

# %% [markdown]
# #### Step 06
# Export the DF as a csv file [WeatherPy_Database.csv]

# %%
#Save the DF
city_data_df.to_csv('WeatherPy_Database.csv', index_label='City_ID')

#Check the DF
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Feels Like  Min Temp  Max Temp  \
# City_ID
# 0               Lagoa  39.0500  -27.9833       62.53     63.00     63.00
# 1              Yarada  17.6500   83.2667       78.66     77.32     77.32
# 2          Marienburg  54.0359   19.0266       23.86     29.89     33.46
# 3            Havelock  34.8791  -76.9013       54.00     50.05     57.15
# 4         Provideniya  64.3833 -173.3000       15.48     26.37     26.71
# 5            Tasiilaq  65.6145  -37.6368       17.31     29.66     29.66
# 6           Carnarvon -24.8667  113.6333       83.32     80.67     80.67
# 7             Rikitea -23.1203 -134.9692       77.67     76.89     76.89
# 8            Behbahan  30.5959   50.2417       45.48     48.16     51.12
# 9        Norman Wells  65.2820 -126.8329      -25.96    -13.36    -13.36
#
#          Humidity  Cloudiness  Wind Speed Country Current Description  \
# City_ID
# 0              75          66       11.48      PT       broken clouds
# 1              83          75        5.75      IN                mist
# 2              88         100       10.38      PL     overcast clouds
# 3              89          50        1.25      US    scattered clouds
# 4              86          75       13.42      RU                snow
# 5              90         100       18.70      GL          light snow
# 6              65           0       17.27      AU           clear sky
# 7              72         100        6.22      PF     overcast clouds
# 8              32          74        5.99      IR       broken clouds
# 9              81          37        5.57      CA    scattered clouds
#
#                         Date
# City_ID
# 0        2021-12-06 02:25:35
# 1        2021-12-06 02:25:36
# 2        2021-12-06 02:25:36
# 3        2021-12-06 02:25:36
# 4        2021-12-06 02:25:37
# 5        2021-12-06 02:25:37
# 6        2021-12-06 02:25:37
# 7        2021-12-06 02:25:38
# 8        2021-12-06 02:25:38
# 9        2021-12-06 02:25:38
